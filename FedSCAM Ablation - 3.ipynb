# %%
import os, copy, math, random, time
from dataclasses import dataclass
from typing import Dict, List, Tuple

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, Subset
import torchvision
import torchvision.transforms as T
import matplotlib.pyplot as plt
import pandas as pd

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(42)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("device:", device)
# Out:
# device: cuda

# %%
@dataclass
class CFG:
    dataset: str = "cifar10"
    num_clients: int = 10
    client_fraction: float = 1.0
    rounds: int = 15
    local_epochs: int = 5
    batch_size: int = 256
    test_batch_size: int = 512

    lr: float = 0.01
    momentum: float = 0.9
    weight_decay: float = 5e-4

    prox_mu: float = 0.001

    sam_rho: float = 0.05
    sam_rho_min: float = 0.01
    sam_rho_max: float = 0.2

    adaptive_rho_mode: str = "grad_norm"

    lw_mode: str = "upweight_hard"
    lw_gamma: float = 1.0  
    lw_eps: float = 1e-8

    qfed_q: float = 1.0

    server_momentum: float = 0.9

    alphas: Tuple[float, ...] = (0.1)

    use_fedbn: bool = False

cfg = CFG()
print(cfg)
# Out:
# CFG(dataset='cifar10', num_clients=10, client_fraction=1.0, rounds=15, local_epochs=2, batch_size=256, test_batch_size=512, lr=0.01, momentum=0.9, weight_decay=0.0005, prox_mu=0.001, sam_rho=0.05, sam_rho_min=0.01, sam_rho_max=0.2, adaptive_rho_mode='grad_norm', lw_mode='upweight_hard', lw_gamma=1.0, lw_eps=1e-08, qfed_q=1.0, server_momentum=0.9, alphas=(0.1, 0.5, 1.0), use_fedbn=False)

# %%
def get_cifar10():
    transform_train = T.Compose([
        T.RandomCrop(32, padding=4),
        T.RandomHorizontalFlip(),
        T.ToTensor(),
        T.Normalize((0.4914, 0.4822, 0.4465), (0.2470, 0.2435, 0.2616)),
    ])
    transform_test = T.Compose([
        T.ToTensor(),
        T.Normalize((0.4914, 0.4822, 0.4465), (0.2470, 0.2435, 0.2616)),
    ])
    trainset = torchvision.datasets.CIFAR10(root="./data", train=True, download=True, transform=transform_train)
    testset  = torchvision.datasets.CIFAR10(root="./data", train=False, download=True, transform=transform_test)
    return trainset, testset

trainset, testset = get_cifar10()
print("train:", len(trainset), "test:", len(testset))

test_loader = DataLoader(testset, batch_size=cfg.test_batch_size, shuffle=False, num_workers=2, pin_memory=True)

def dirichlet_partition(dataset, num_clients: int, alpha: float, num_classes: int = 10, seed: int = 42):
    rng = np.random.default_rng(seed)
    targets = np.array(dataset.targets)

    class_indices = [np.where(targets == c)[0] for c in range(num_classes)]
    for c in range(num_classes):
        rng.shuffle(class_indices[c])

    client_indices = [[] for _ in range(num_clients)]

    for c in range(num_classes):
        proportions = rng.dirichlet([alpha] * num_clients)
        proportions = proportions / proportions.sum()

        idx_c = class_indices[c]
        splits = (np.cumsum(proportions) * len(idx_c)).astype(int)[:-1]
        parts = np.split(idx_c, splits)

        for k in range(num_clients):
            client_indices[k].extend(parts[k].tolist())

    for k in range(num_clients):
        rng.shuffle(client_indices[k])

    return client_indices

def make_client_loaders(dataset, client_indices, batch_size: int, shuffle=True):
    loaders = []
    for idxs in client_indices:
        subset = Subset(dataset, idxs)
        loader = DataLoader(subset, batch_size=batch_size, shuffle=shuffle, num_workers=2, pin_memory=True, drop_last=False)
        loaders.append(loader)
    return loaders

def summarize_split(dataset, client_indices, num_classes=10):
    targets = np.array(dataset.targets)
    rows = []
    for k, idxs in enumerate(client_indices):
        y = targets[idxs]
        counts = [(y == c).sum() for c in range(num_classes)]
        rows.append([k, len(idxs)] + counts)
    cols = ["client", "n"] + [f"class_{c}" for c in range(num_classes)]
    return pd.DataFrame(rows, columns=cols)

tmp_idx = dirichlet_partition(trainset, cfg.num_clients, alpha=0.1, seed=42)
display(summarize_split(trainset, tmp_idx).head())
# Out:
# train: 50000 test: 10000
#    client     n  class_0  class_1  class_2  class_3  class_4  class_5  \
# 0       0  6659     2036        0        0       69     1248     2579
# 1       1  4815      226     1419       37        0      337        0
# 2       2  5554      238     1274        0        0        0        0
# 3       3  6790        0        0     1470        0       15        4
# 4       4  5327        0        1        3     2442      148      342
#
#    class_6  class_7  class_8  class_9
# 0      507      218        2        0
# 1      223       47        0     2526
# 2     4008       34        0        0
# 3      235      136     4930        0
# 4       16     1212        0     1163

# %%
class SmallCNN(nn.Module):
    def __init__(self, num_classes=10):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 32, 3, padding=1)
        self.bn1   = nn.BatchNorm2d(32)
        self.conv2 = nn.Conv2d(32, 64, 3, padding=1)
        self.bn2   = nn.BatchNorm2d(64)
        self.pool  = nn.MaxPool2d(2, 2)

        self.conv3 = nn.Conv2d(64, 128, 3, padding=1)
        self.bn3   = nn.BatchNorm2d(128)
        self.pool2 = nn.MaxPool2d(2, 2)

        self.fc1   = nn.Linear(128 * 8 * 8, 256)
        self.fc2   = nn.Linear(256, num_classes)

    def forward(self, x):
        x = self.pool(F.relu(self.bn1(self.conv1(x))))
        x = self.pool2(F.relu(self.bn2(self.conv2(x))))
        x = F.relu(self.bn3(self.conv3(x)))
        x = x.flatten(1)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

def build_model():
    return SmallCNN(num_classes=10)

loss_fn = nn.CrossEntropyLoss()

# %%
@torch.no_grad()
def evaluate(model, loader):
    model.eval()
    total, correct, total_loss = 0, 0, 0.0
    for x, y in loader:
        x, y = x.to(device), y.to(device)
        logits = model(x)
        loss = loss_fn(logits, y)
        total_loss += loss.item() * y.size(0)
        pred = logits.argmax(dim=1)
        correct += (pred == y).sum().item()
        total += y.size(0)
    return total_loss / total, correct / total

def is_bn_key(k: str) -> bool:
    return (".bn" in k) or ("bn" in k and ("running_mean" in k or "running_var" in k or "num_batches_tracked" in k))

def aggregate_state_dicts(
    global_state: Dict[str, torch.Tensor],
    client_states: List[Dict[str, torch.Tensor]],
    weights: List[float],
    use_fedbn: bool
):
    new_state = {}
    wsum = sum(weights) + 1e-12
    for k in global_state.keys():
        if use_fedbn and is_bn_key(k):
            new_state[k] = global_state[k].clone()
            continue

        acc = None
        for sd, w in zip(client_states, weights):
            t = sd[k].to(global_state[k].device)
            if acc is None:
                acc = (w / wsum) * t
            else:
                acc += (w / wsum) * t
        new_state[k] = acc
    return new_state

def sample_clients(num_clients, fraction, rng):
    m = max(1, int(round(num_clients * fraction)))
    return rng.choice(num_clients, size=m, replace=False).tolist()

# %%
def grad_norm(model: nn.Module) -> torch.Tensor:
    norms = []
    for p in model.parameters():
        if p.grad is None:
            continue
        norms.append(torch.norm(p.grad.detach(), p=2))
    if len(norms) == 0:
        return torch.tensor(0.0, device=device)
    return torch.norm(torch.stack(norms), p=2)

@torch.no_grad()
def add_scaled_grad_(model: nn.Module, scale: float):
    for p in model.parameters():
        if p.grad is None:
            continue
        p.add_(p.grad, alpha=scale)

@torch.no_grad()
def save_params(model: nn.Module):
    return [p.detach().clone() for p in model.parameters()]

@torch.no_grad()
def load_params(model: nn.Module, params_backup):
    for p, b in zip(model.parameters(), params_backup):
        p.copy_(b)

def sam_batch_update(model, optimizer, x, y, rho: float):
    model.train()
    optimizer.zero_grad(set_to_none=True)
    logits = model(x)
    loss = loss_fn(logits, y)
    loss.backward()

    gnorm = grad_norm(model)
    scale = rho / (gnorm + 1e-12)

    backup = save_params(model)
    add_scaled_grad_(model, scale)

    optimizer.zero_grad(set_to_none=True)
    logits2 = model(x)
    loss2 = loss_fn(logits2, y)
    loss2.backward()

    load_params(model, backup)
    optimizer.step()

    return loss.item(), loss2.item(), gnorm.item()

# %%
def make_optimizer(model):
    return torch.optim.SGD(model.parameters(), lr=cfg.lr, momentum=cfg.momentum, weight_decay=cfg.weight_decay)

def local_train_sgd(model, loader, epochs=1):
    model.train()
    opt = make_optimizer(model)
    total_loss, total_n = 0.0, 0
    for _ in range(epochs):
        for x, y in loader:
            x, y = x.to(device), y.to(device)
            opt.zero_grad(set_to_none=True)
            logits = model(x)
            loss = loss_fn(logits, y)
            loss.backward()
            opt.step()
            total_loss += loss.item() * y.size(0)
            total_n += y.size(0)
    return total_loss / max(1, total_n)

def local_train_fedprox(model, global_model, loader, epochs=1, mu=0.001):
    model.train()
    opt = make_optimizer(model)
    g_params = [p.detach().clone() for p in global_model.parameters()]
    total_loss, total_n = 0.0, 0

    for _ in range(epochs):
        for x, y in loader:
            x, y = x.to(device), y.to(device)
            opt.zero_grad(set_to_none=True)
            logits = model(x)
            loss = loss_fn(logits, y)

            prox = 0.0
            for p, gp in zip(model.parameters(), g_params):
                prox = prox + (p - gp).pow(2).sum()
            loss = loss + (mu / 2.0) * prox

            loss.backward()
            opt.step()

            total_loss += loss.item() * y.size(0)
            total_n += y.size(0)

    return total_loss / max(1, total_n)

def local_train_fedsam(model, loader, epochs=1, rho=0.05):
    opt = make_optimizer(model)
    total_loss, total_n = 0.0, 0
    for _ in range(epochs):
        for x, y in loader:
            x, y = x.to(device), y.to(device)
            l1, l2, _ = sam_batch_update(model, opt, x, y, rho=rho)
            total_loss += l2 * y.size(0)
            total_n += y.size(0)
    return total_loss / max(1, total_n)

def compute_adaptive_rho(client_stat: float, ref_stat: float, rho0: float, rho_min: float, rho_max: float):
    ratio = client_stat / (ref_stat + 1e-12)
    rho = rho0 * ratio
    return float(np.clip(rho, rho_min, rho_max))

@torch.no_grad()
def get_one_batch(loader):
    for x, y in loader:
        return x.to(device), y.to(device)
    raise RuntimeError("empty loader")

def client_probe_stats(model, loader):
    model.train()
    x, y = get_one_batch(loader)
    for p in model.parameters():
        if p.grad is not None:
            p.grad = None
    logits = model(x)
    loss = loss_fn(logits, y)
    loss.backward()
    gn = grad_norm(model).item()
    return loss.item(), gn

def local_train_adaptive_sam(model, loader, epochs, rho_for_client: float):
    opt = make_optimizer(model)
    total_loss, total_n = 0.0, 0
    for _ in range(epochs):
        for x, y in loader:
            x, y = x.to(device), y.to(device)
            _, l2, _ = sam_batch_update(model, opt, x, y, rho=rho_for_client)
            total_loss += l2 * y.size(0)
            total_n += y.size(0)
    return total_loss / max(1, total_n)

@torch.no_grad()
def apply_global_perturbation(model, direction_state, rho):
    for name, p in model.named_parameters():
        if name in direction_state:
            d = direction_state[name].to(p.device)
            p.add_(d, alpha=rho)

@torch.no_grad()
def remove_global_perturbation(model, direction_state, rho):
    for name, p in model.named_parameters():
        if name in direction_state:
            d = direction_state[name].to(p.device)
            p.add_(d, alpha=-rho)

def normalize_direction_state(direction_state):
    sq = 0.0
    for v in direction_state.values():
        sq += (v.detach().float().norm(p=2) ** 2).item()
    norm = math.sqrt(sq) + 1e-12
    out = {k: (v / norm) for k, v in direction_state.items()}
    return out, norm

def local_train_lesam(model, loader, epochs, global_direction_state, rho):
    opt = make_optimizer(model)
    total_loss, total_n = 0.0, 0

    for _ in range(epochs):
        for x, y in loader:
            x, y = x.to(device), y.to(device)

            apply_global_perturbation(model, global_direction_state, rho)

            opt.zero_grad(set_to_none=True)
            logits = model(x)
            loss = loss_fn(logits, y)
            loss.backward()

            remove_global_perturbation(model, global_direction_state, rho)
            opt.step()

            total_loss += loss.item() * y.size(0)
            total_n += y.size(0)

    return total_loss / max(1, total_n)

# %%
def weights_fedavg(client_sizes):
    return [float(n) for n in client_sizes]

def weights_uniform(num_clients):
    return [1.0] * num_clients

def weights_fedlw(client_sizes, client_losses, mode="upweight_hard", gamma=1.0, eps=1e-8):
    ws = []
    for n, l in zip(client_sizes, client_losses):
        if mode == "upweight_hard":
            ws.append(float(n) * float((l + eps) ** gamma))
        else:
            ws.append(float(n) / float((l + eps) ** gamma))
    return ws

def weights_qfedavg(client_sizes, client_losses, q=1.0, eps=1e-8):
    return [float(n) * float((l + eps) ** q) for n, l in zip(client_sizes, client_losses)]

# %%
def state_dict_to_cpu(sd):
    return {k: v.detach().cpu().clone() for k, v in sd.items()}

def run_one_alpha(alpha: float, seed: int = 42):
    rng = np.random.default_rng(seed)

    client_indices = dirichlet_partition(trainset, cfg.num_clients, alpha=alpha, seed=seed)
    client_loaders = make_client_loaders(trainset, client_indices, batch_size=cfg.batch_size, shuffle=True)

    client_sizes = [len(idxs) for idxs in client_indices]

    WA_ALGOS = [
        "FedAvg",
        "Uniform",
        "FedProx",
        "qFedAvg",
        "FedAvgM",   
        "FedLW",        
        "FedSCAM_WA", 
    ]

    SAM_ALGOS = [
        "FedSAM",
        "FedLESAM",
        "FedWMSAM",    
        "FedLWSAM",    
        "FedSCAM_SAM",  
    ]

    FULL_ALGOS = ["FedSCAM_FULL"]

    ALL_ALGOS = WA_ALGOS + SAM_ALGOS + FULL_ALGOS

    results = {algo: {"acc": [], "loss": []} for algo in ALL_ALGOS}

    server_momentum_buffers = {algo: None for algo in ALL_ALGOS}

    for algo in ALL_ALGOS:
        global_model = build_model().to(device)
        global_state = copy.deepcopy(global_model.state_dict())

        server_m = None 
        if algo in ["FedAvgM", "FedWMSAM"] or "AvgM" in algo:
            server_m = {k: torch.zeros_like(v) for k, v in global_state.items()}

        print(f"\n=== alpha={alpha} | algo={algo} ===")
        for r in range(1, cfg.rounds + 1):
            selected = sample_clients(cfg.num_clients, cfg.client_fraction, rng)

            probe_losses = []
            probe_gns = []
            probe_grads = []

            if algo in ["FedSCAM_SAM", "FedSCAM_FULL", "FedLESAM"]:
                for k in selected:
                    m = build_model().to(device)
                    m.load_state_dict(global_state)
                    l, gn = client_probe_stats(m, client_loaders[k])
                    probe_losses.append(l)
                    probe_gns.append(gn)

                    if algo == "FedLESAM":
                        gstate = {}
                        for name, p in m.named_parameters():
                            if p.grad is None:
                                continue
                            gstate[name] = p.grad.detach().clone()
                        probe_grads.append(gstate)

                ref_loss = float(np.mean(probe_losses)) if len(probe_losses) else 1.0
                ref_gn   = float(np.mean(probe_gns)) if len(probe_gns) else 1.0

                if algo == "FedLESAM":
                    avg_g = {}
                    for gstate in probe_grads:
                        for name, g in gstate.items():
                            if name not in avg_g:
                                avg_g[name] = g.detach().clone()
                            else:
                                avg_g[name] += g.detach().clone()
                    for name in avg_g:
                        avg_g[name] /= max(1, len(probe_grads))
                    avg_g, _ = normalize_direction_state(avg_g)
                else:
                    avg_g = None
            else:
                ref_loss, ref_gn, avg_g = None, None, None

            client_states = []
            client_train_losses = []
            selected_sizes = []

            for k in selected:
                local_model = build_model().to(device)
                local_model.load_state_dict(global_state)

                if algo in ["FedAvg", "Uniform", "FedLW", "FedSCAM_WA", "qFedAvg", "FedAvgM"]:
                    if algo == "FedProx":
                        raise RuntimeError("FedProx handled below")
                    tr_loss = local_train_sgd(local_model, client_loaders[k], epochs=cfg.local_epochs)

                elif algo == "FedProx":
                    gmodel = build_model().to(device)
                    gmodel.load_state_dict(global_state)
                    tr_loss = local_train_fedprox(local_model, gmodel, client_loaders[k],
                                                  epochs=cfg.local_epochs, mu=cfg.prox_mu)

                elif algo in ["FedSAM", "FedWMSAM", "FedLWSAM"]:
                    tr_loss = local_train_fedsam(local_model, client_loaders[k],
                                                 epochs=cfg.local_epochs, rho=cfg.sam_rho)

                elif algo in ["FedSCAM_SAM", "FedSCAM_FULL"]:
                    if cfg.adaptive_rho_mode == "loss":
                        idx = selected.index(k)
                        stat = probe_losses[idx]
                        ref  = ref_loss
                    else:
                        idx = selected.index(k)
                        stat = probe_gns[idx]
                        ref  = ref_gn

                    rho_k = compute_adaptive_rho(stat, ref, cfg.sam_rho, cfg.sam_rho_min, cfg.sam_rho_max)
                    tr_loss = local_train_adaptive_sam(local_model, client_loaders[k],
                                                       epochs=cfg.local_epochs, rho_for_client=rho_k)

                elif algo == "FedLESAM":
                    tr_loss = local_train_lesam(local_model, client_loaders[k],
                                                epochs=cfg.local_epochs,
                                                global_direction_state=avg_g,
                                                rho=cfg.sam_rho)

                elif algo == "FedSCAM_FULL":
                    raise RuntimeError("FedSCAM_FULL handled above")

                else:
                    raise ValueError(f"Unknown algo: {algo}")

                client_states.append(copy.deepcopy(local_model.state_dict()))
                client_train_losses.append(float(tr_loss))
                selected_sizes.append(client_sizes[k])

            if algo == "FedAvg":
                agg_w = weights_fedavg(selected_sizes)
            elif algo == "Uniform":
                agg_w = weights_uniform(len(selected))
            elif algo == "FedProx":
                agg_w = weights_fedavg(selected_sizes)
            elif algo == "qFedAvg":
                agg_w = weights_qfedavg(selected_sizes, client_train_losses, q=cfg.qfed_q, eps=cfg.lw_eps)
            elif algo == "FedAvgM":
                agg_w = weights_fedavg(selected_sizes)
            elif algo == "FedLW":
                agg_w = weights_fedlw(selected_sizes, client_train_losses, mode=cfg.lw_mode,
                                      gamma=cfg.lw_gamma, eps=cfg.lw_eps)
            elif algo == "FedSCAM_WA":
                agg_w = weights_fedlw(selected_sizes, client_train_losses, mode=cfg.lw_mode,
                                      gamma=cfg.lw_gamma, eps=cfg.lw_eps)
            elif algo == "FedSAM":
                agg_w = weights_fedavg(selected_sizes)
            elif algo == "FedLESAM":
                agg_w = weights_fedavg(selected_sizes)
            elif algo == "FedWMSAM":
                agg_w = weights_fedavg(selected_sizes)
            elif algo == "FedLWSAM":
                agg_w = weights_fedlw(selected_sizes, client_train_losses, mode=cfg.lw_mode,
                                      gamma=cfg.lw_gamma, eps=cfg.lw_eps)
            elif algo == "FedSCAM_SAM":
                agg_w = weights_fedavg(selected_sizes)
            elif algo == "FedSCAM_FULL":
                agg_w = weights_fedlw(selected_sizes, client_train_losses, mode=cfg.lw_mode,
                                      gamma=cfg.lw_gamma, eps=cfg.lw_eps)
            else:
                agg_w = weights_fedavg(selected_sizes)

            if algo in ["FedAvgM", "FedWMSAM"]:
                new_avg_state = aggregate_state_dicts(global_state, client_states, agg_w, use_fedbn=cfg.use_fedbn)
                delta = {k: (new_avg_state[k] - global_state[k]) for k in global_state.keys()}

                beta = cfg.server_momentum
                for k in server_m:
                    server_m[k] = beta * server_m[k] + (1.0 - beta) * delta[k]

                global_state = {k: (global_state[k] + server_m[k]) for k in global_state.keys()}
            else:
                global_state = aggregate_state_dicts(global_state, client_states, agg_w, use_fedbn=cfg.use_fedbn)

            global_model.load_state_dict(global_state)
            te_loss, te_acc = evaluate(global_model, test_loader)
            results[algo]["acc"].append(te_acc)
            results[algo]["loss"].append(te_loss)

            print(f"Round {r:02d}/{cfg.rounds} | test_acc={te_acc*100:.2f}% | test_loss={te_loss:.4f}")

    return results

def plot_group(results_alpha, alpha, algos, title):
    plt.figure(figsize=(10, 5))
    for a in algos:
        plt.plot(np.arange(1, cfg.rounds+1), results_alpha[a]["acc"], label=a)
    plt.xlabel("Round")
    plt.ylabel("Test Accuracy")
    plt.title(f"{title} | alpha={alpha}")
    plt.grid(True)
    plt.legend()
    plt.show()

def final_table(all_results):
    rows = []
    for alpha, res in all_results.items():
        for algo, vals in res.items():
            rows.append({
                "alpha": alpha,
                "algo": algo,
                "final_acc": vals["acc"][-1],
                "best_acc": max(vals["acc"]),
            })
    df = pd.DataFrame(rows).sort_values(["alpha", "final_acc"], ascending=[True, False])
    return df

all_results = {}
for a in cfg.alphas:
    all_results[a] = run_one_alpha(alpha=a, seed=42)

df = final_table(all_results)
display(df)
# Out:
# === alpha=0.1 | algo=FedAvg ===
# Round 01/15 | test_acc=28.41% | test_loss=2.1681
# Round 02/15 | test_acc=33.63% | test_loss=1.8266
# Round 03/15 | test_acc=36.82% | test_loss=1.7617
# Round 04/15 | test_acc=39.53% | test_loss=1.6837
# Round 05/15 | test_acc=41.44% | test_loss=1.6449
# Round 06/15 | test_acc=41.00% | test_loss=1.6725
# Round 07/15 | test_acc=40.96% | test_loss=1.6227
# Round 08/15 | test_acc=42.72% | test_loss=1.6121
# Round 09/15 | test_acc=44.91% | test_loss=1.5273
# Round 10/15 | test_acc=45.08% | test_loss=1.5275
# Round 11/15 | test_acc=45.75% | test_loss=1.4914
# Round 12/15 | test_acc=40.46% | test_loss=1.6150
# Round 13/15 | test_acc=43.94% | test_loss=1.5150
# Round 14/15 | test_acc=42.93% | test_loss=1.4763
# Round 15/15 | test_acc=50.36% | test_loss=1.4023
#
# === alpha=0.1 | algo=Uniform ===
# Round 01/15 | test_acc=26.91% | test_loss=2.1943
# Round 02/15 | test_acc=36.21% | test_loss=1.8294
# Round 03/15 | test_acc=38.16% | test_loss=1.8136
# Round 04/15 | test_acc=37.01% | test_loss=1.7891
# Round 05/15 | test_acc=31.65% | test_loss=1.8386
# Round 06/15 | test_acc=37.05% | test_loss=1.7365
# Round 07/15 | test_acc=35.35% | test_loss=1.7407
# Round 08/15 | test_acc=44.42% | test_loss=1.5983
# Round 09/15 | test_acc=39.99% | test_loss=1.6214
# Round 10/15 | test_acc=46.20% | test_loss=1.5518
# Round 11/15 | test_acc=42.06% | test_loss=1.5487
# Round 12/15 | test_acc=47.72% | test_loss=1.5023
# Round 13/15 | test_acc=44.75% | test_loss=1.4697
# Round 14/15 | test_acc=44.37% | test_loss=1.5557
# Round 15/15 | test_acc=45.23% | test_loss=1.4622
#
# === alpha=0.1 | algo=FedProx ===
# Round 01/15 | test_acc=31.02% | test_loss=2.1556
# Round 02/15 | test_acc=33.24% | test_loss=1.8514
# Round 03/15 | test_acc=36.01% | test_loss=1.7667
# Round 04/15 | test_acc=38.52% | test_loss=1.6956
# Round 05/15 | test_acc=38.62% | test_loss=1.6849
# Round 06/15 | test_acc=38.30% | test_loss=1.7048
# Round 07/15 | test_acc=39.98% | test_loss=1.6341
# Round 08/15 | test_acc=39.47% | test_loss=1.6797
# Round 09/15 | test_acc=41.44% | test_loss=1.6078
# Round 10/15 | test_acc=45.43% | test_loss=1.5399
# Round 11/15 | test_acc=44.03% | test_loss=1.5599
# Round 12/15 | test_acc=47.36% | test_loss=1.4698
# Round 13/15 | test_acc=44.41% | test_loss=1.5390
# Round 14/15 | test_acc=48.73% | test_loss=1.4463
# Round 15/15 | test_acc=44.14% | test_loss=1.4906
#
# === alpha=0.1 | algo=qFedAvg ===
# Round 01/15 | test_acc=27.03% | test_loss=2.1558
# Round 02/15 | test_acc=35.16% | test_loss=1.8519
# Round 03/15 | test_acc=36.44% | test_loss=1.8097
# Round 04/15 | test_acc=37.68% | test_loss=1.7342
# Round 05/15 | test_acc=41.46% | test_loss=1.7048
# Round 06/15 | test_acc=42.48% | test_loss=1.6251
# Round 07/15 | test_acc=45.59% | test_loss=1.5709
# Round 08/15 | test_acc=42.69% | test_loss=1.5953
# Round 09/15 | test_acc=44.79% | test_loss=1.5473
# Round 10/15 | test_acc=43.45% | test_loss=1.5464
# Round 11/15 | test_acc=45.62% | test_loss=1.4840
# Round 12/15 | test_acc=42.58% | test_loss=1.5575
# Round 13/15 | test_acc=45.77% | test_loss=1.4485
# Round 14/15 | test_acc=41.66% | test_loss=1.6090
# Round 15/15 | test_acc=48.67% | test_loss=1.3681
#
# === alpha=0.1 | algo=FedAvgM ===
# Round 01/15 | test_acc=12.58% | test_loss=2.2995
# Round 02/15 | test_acc=19.34% | test_loss=2.2908
# Round 03/15 | test_acc=15.03% | test_loss=2.2696
# Round 04/15 | test_acc=17.34% | test_loss=2.2143
# Round 05/15 | test_acc=33.18% | test_loss=2.0016
# Round 06/15 | test_acc=10.00% | test_loss=nan
# Round 07/15 | test_acc=10.00% | test_loss=nan
# Round 08/15 | test_acc=10.00% | test_loss=nan
# Round 09/15 | test_acc=10.00% | test_loss=nan
# Round 10/15 | test_acc=10.00% | test_loss=nan
# Round 11/15 | test_acc=10.00% | test_loss=nan
# Round 12/15 | test_acc=10.00% | test_loss=nan
# Round 13/15 | test_acc=10.00% | test_loss=nan
# Round 14/15 | test_acc=9.97% | test_loss=5.2630
# Round 15/15 | test_acc=43.39% | test_loss=1.6029
#
# === alpha=0.1 | algo=FedLW ===
# Round 01/15 | test_acc=24.23% | test_loss=2.1818
# Round 02/15 | test_acc=31.40% | test_loss=1.8738
# Round 03/15 | test_acc=36.15% | test_loss=1.8089
# Round 04/15 | test_acc=35.69% | test_loss=1.7884
# Round 05/15 | test_acc=40.57% | test_loss=1.6730
# Round 06/15 | test_acc=41.66% | test_loss=1.6641
# Round 07/15 | test_acc=38.30% | test_loss=1.6948
# Round 08/15 | test_acc=43.60% | test_loss=1.6009
# Round 09/15 | test_acc=38.08% | test_loss=1.7165
# Round 10/15 | test_acc=42.25% | test_loss=1.5738
# Round 11/15 | test_acc=42.56% | test_loss=1.5747
# Round 12/15 | test_acc=47.17% | test_loss=1.4854
# Round 13/15 | test_acc=45.58% | test_loss=1.5099
# Round 14/15 | test_acc=48.46% | test_loss=1.4252
# Round 15/15 | test_acc=47.64% | test_loss=1.4653
#
# === alpha=0.1 | algo=FedSCAM_WA ===
# Round 01/15 | test_acc=24.38% | test_loss=2.1568
# Round 02/15 | test_acc=33.32% | test_loss=1.8595
# Round 03/15 | test_acc=32.11% | test_loss=1.8689
# Round 04/15 | test_acc=37.25% | test_loss=1.7729
# Round 05/15 | test_acc=36.91% | test_loss=1.7888
# Round 06/15 | test_acc=41.53% | test_loss=1.6805
# Round 07/15 | test_acc=40.60% | test_loss=1.6609
# Round 08/15 | test_acc=40.16% | test_loss=1.6399
# Round 09/15 | test_acc=34.06% | test_loss=1.7432
# Round 10/15 | test_acc=41.26% | test_loss=1.6133
# Round 11/15 | test_acc=40.90% | test_loss=1.5763
# Round 12/15 | test_acc=43.16% | test_loss=1.5584
# Round 13/15 | test_acc=42.41% | test_loss=1.5280
# Round 14/15 | test_acc=46.96% | test_loss=1.4624
# Round 15/15 | test_acc=48.39% | test_loss=1.4158
#
# === alpha=0.1 | algo=FedSAM ===
# Round 01/15 | test_acc=17.98% | test_loss=2.2445
# Round 02/15 | test_acc=30.71% | test_loss=2.0141
# Round 03/15 | test_acc=37.50% | test_loss=1.9842
# Round 04/15 | test_acc=36.89% | test_loss=1.8279
# Round 05/15 | test_acc=38.18% | test_loss=1.8326
# Round 06/15 | test_acc=41.09% | test_loss=1.7506
# Round 07/15 | test_acc=40.69% | test_loss=1.7365
# Round 08/15 | test_acc=42.65% | test_loss=1.6741
# Round 09/15 | test_acc=43.57% | test_loss=1.6722
# Round 10/15 | test_acc=43.75% | test_loss=1.6430
# Round 11/15 | test_acc=45.08% | test_loss=1.6297
# Round 12/15 | test_acc=45.03% | test_loss=1.6034
# Round 13/15 | test_acc=46.08% | test_loss=1.6186
# Round 14/15 | test_acc=45.56% | test_loss=1.5763
# Round 15/15 | test_acc=46.92% | test_loss=1.5641
#
# === alpha=0.1 | algo=FedLESAM ===
# Round 01/15 | test_acc=26.48% | test_loss=2.1820
# Round 02/15 | test_acc=34.89% | test_loss=1.8024
# Round 03/15 | test_acc=26.20% | test_loss=1.9589
# Round 04/15 | test_acc=34.76% | test_loss=1.8252
# Round 05/15 | test_acc=27.39% | test_loss=1.9411
# Round 06/15 | test_acc=34.57% | test_loss=1.7793
# Round 07/15 | test_acc=34.61% | test_loss=1.7209
# Round 08/15 | test_acc=35.01% | test_loss=1.7668
# Round 09/15 | test_acc=39.98% | test_loss=1.6919
# Round 10/15 | test_acc=41.53% | test_loss=1.5693
# Round 11/15 | test_acc=41.78% | test_loss=1.6309
# Round 12/15 | test_acc=43.04% | test_loss=1.5994
# Round 13/15 | test_acc=44.95% | test_loss=1.5595
# Round 14/15 | test_acc=49.12% | test_loss=1.4521
# Round 15/15 | test_acc=46.25% | test_loss=1.5172
#
# === alpha=0.1 | algo=FedWMSAM ===
# Round 01/15 | test_acc=12.43% | test_loss=2.3007
# Round 02/15 | test_acc=14.68% | test_loss=2.2978
# Round 03/15 | test_acc=21.06% | test_loss=2.2876
# Round 04/15 | test_acc=20.33% | test_loss=2.2485
# Round 05/15 | test_acc=29.89% | test_loss=2.1161
# Round 06/15 | test_acc=10.00% | test_loss=nan
# Round 07/15 | test_acc=10.00% | test_loss=nan
# Round 08/15 | test_acc=10.00% | test_loss=nan
# Round 09/15 | test_acc=10.00% | test_loss=nan
# Round 10/15 | test_acc=10.00% | test_loss=nan
# Round 11/15 | test_acc=10.00% | test_loss=nan
# Round 12/15 | test_acc=10.00% | test_loss=nan
# Round 13/15 | test_acc=10.00% | test_loss=nan
# Round 14/15 | test_acc=9.97% | test_loss=2.9729
# Round 15/15 | test_acc=37.39% | test_loss=1.7626
#
# === alpha=0.1 | algo=FedLWSAM ===
# Round 01/15 | test_acc=19.44% | test_loss=2.2511
# Round 02/15 | test_acc=28.95% | test_loss=2.0023
# Round 03/15 | test_acc=28.43% | test_loss=1.9661
# Round 04/15 | test_acc=37.11% | test_loss=1.8445
# Round 05/15 | test_acc=35.99% | test_loss=1.8197
# Round 06/15 | test_acc=40.00% | test_loss=1.7896
# Round 07/15 | test_acc=38.14% | test_loss=1.7459
# Round 08/15 | test_acc=42.05% | test_loss=1.7014
# Round 09/15 | test_acc=41.49% | test_loss=1.6893
# Round 10/15 | test_acc=44.21% | test_loss=1.6500
# Round 11/15 | test_acc=41.03% | test_loss=1.6857
# Round 12/15 | test_acc=46.60% | test_loss=1.6052
# Round 13/15 | test_acc=42.75% | test_loss=1.6431
# Round 14/15 | test_acc=47.67% | test_loss=1.5575
# Round 15/15 | test_acc=44.53% | test_loss=1.5764
#
# === alpha=0.1 | algo=FedSCAM_SAM ===
# Round 01/15 | test_acc=21.55% | test_loss=2.2518
# Round 02/15 | test_acc=30.52% | test_loss=1.9656
# Round 03/15 | test_acc=36.00% | test_loss=1.9811
# Round 04/15 | test_acc=33.71% | test_loss=1.8605
# Round 05/15 | test_acc=40.34% | test_loss=1.7649
# Round 06/15 | test_acc=38.97% | test_loss=1.7516
# Round 07/15 | test_acc=42.21% | test_loss=1.7095
# Round 08/15 | test_acc=42.73% | test_loss=1.6925
# Round 09/15 | test_acc=42.69% | test_loss=1.6518
# Round 10/15 | test_acc=44.20% | test_loss=1.6434
# Round 11/15 | test_acc=45.06% | test_loss=1.6237
# Round 12/15 | test_acc=46.85% | test_loss=1.5841
# Round 13/15 | test_acc=47.05% | test_loss=1.5641
# Round 14/15 | test_acc=48.03% | test_loss=1.5609
# Round 15/15 | test_acc=48.77% | test_loss=1.5290
#
# === alpha=0.1 | algo=FedSCAM_FULL ===
# Round 01/15 | test_acc=20.69% | test_loss=2.2530
# Round 02/15 | test_acc=30.52% | test_loss=1.9897
# Round 03/15 | test_acc=35.05% | test_loss=1.9699
# Round 04/15 | test_acc=36.29% | test_loss=1.8421
# Round 05/15 | test_acc=37.72% | test_loss=1.7974
# Round 06/15 | test_acc=37.69% | test_loss=1.7862
# Round 07/15 | test_acc=39.70% | test_loss=1.7446
# Round 08/15 | test_acc=41.58% | test_loss=1.7066
# Round 09/15 | test_acc=42.15% | test_loss=1.7064
# Round 10/15 | test_acc=43.50% | test_loss=1.6400
# Round 11/15 | test_acc=44.82% | test_loss=1.6305
# Round 12/15 | test_acc=46.18% | test_loss=1.5891
# Round 13/15 | test_acc=46.53% | test_loss=1.5672
# Round 14/15 | test_acc=46.11% | test_loss=1.5465
# Round 15/15 | test_acc=47.97% | test_loss=1.5167
#
# === alpha=0.5 | algo=FedAvg ===
# Round 01/15 | test_acc=36.08% | test_loss=1.8396
# Round 02/15 | test_acc=42.14% | test_loss=1.4867
# Round 03/15 | test_acc=51.62% | test_loss=1.3222
# Round 04/15 | test_acc=51.40% | test_loss=1.2821
# Round 05/15 | test_acc=57.86% | test_loss=1.1604
# Round 06/15 | test_acc=57.54% | test_loss=1.1559
# Round 07/15 | test_acc=61.25% | test_loss=1.0795
# Round 08/15 | test_acc=60.49% | test_loss=1.0697
# Round 09/15 | test_acc=64.51% | test_loss=0.9889
# Round 10/15 | test_acc=63.66% | test_loss=0.9942
# Round 11/15 | test_acc=65.56% | test_loss=0.9506
# Round 12/15 | test_acc=66.69% | test_loss=0.9219
# Round 13/15 | test_acc=67.89% | test_loss=0.8900
# Round 14/15 | test_acc=67.85% | test_loss=0.8902
# Round 15/15 | test_acc=69.68% | test_loss=0.8448
#
# === alpha=0.5 | algo=Uniform ===
# Round 01/15 | test_acc=32.59% | test_loss=1.9118
# Round 02/15 | test_acc=44.45% | test_loss=1.4949
# Round 03/15 | test_acc=47.99% | test_loss=1.3931
# Round 04/15 | test_acc=51.92% | test_loss=1.3000
# Round 05/15 | test_acc=56.09% | test_loss=1.1997
# Round 06/15 | test_acc=57.60% | test_loss=1.1567
# Round 07/15 | test_acc=61.41% | test_loss=1.0869
# Round 08/15 | test_acc=59.30% | test_loss=1.1003
# Round 09/15 | test_acc=63.39% | test_loss=1.0255
# Round 10/15 | test_acc=63.62% | test_loss=1.0065
# Round 11/15 | test_acc=66.03% | test_loss=0.9591
# Round 12/15 | test_acc=66.55% | test_loss=0.9371
# Round 13/15 | test_acc=68.15% | test_loss=0.9037
# Round 14/15 | test_acc=67.74% | test_loss=0.9030
# Round 15/15 | test_acc=69.02% | test_loss=0.8928
#
# === alpha=0.5 | algo=FedProx ===
# Round 01/15 | test_acc=29.84% | test_loss=1.8856
# Round 02/15 | test_acc=43.43% | test_loss=1.5019
# Round 03/15 | test_acc=46.10% | test_loss=1.4102
# Round 04/15 | test_acc=54.87% | test_loss=1.2263
# Round 05/15 | test_acc=53.17% | test_loss=1.2320
# Round 06/15 | test_acc=60.95% | test_loss=1.0875
# Round 07/15 | test_acc=58.66% | test_loss=1.1141
# Round 08/15 | test_acc=63.27% | test_loss=1.0107
# Round 09/15 | test_acc=64.00% | test_loss=0.9735
# Round 10/15 | test_acc=64.93% | test_loss=0.9618
# Round 11/15 | test_acc=66.12% | test_loss=0.9371
# Round 12/15 | test_acc=67.97% | test_loss=0.8913
# Round 13/15 | test_acc=68.20% | test_loss=0.8764
# Round 14/15 | test_acc=70.07% | test_loss=0.8466
# Round 15/15 | test_acc=69.48% | test_loss=0.8499
#
# === alpha=0.5 | algo=qFedAvg ===
# Round 01/15 | test_acc=37.53% | test_loss=1.8156
# Round 02/15 | test_acc=45.13% | test_loss=1.4574
# Round 03/15 | test_acc=50.33% | test_loss=1.3309
# Round 04/15 | test_acc=54.62% | test_loss=1.2313
# Round 05/15 | test_acc=58.09% | test_loss=1.1477
# Round 06/15 | test_acc=59.33% | test_loss=1.1052
# Round 07/15 | test_acc=62.70% | test_loss=1.0404
# Round 08/15 | test_acc=64.11% | test_loss=0.9945
# Round 09/15 | test_acc=65.69% | test_loss=0.9687
# Round 10/15 | test_acc=65.78% | test_loss=0.9538
# Round 11/15 | test_acc=67.02% | test_loss=0.9246
# Round 12/15 | test_acc=66.19% | test_loss=0.9241
# Round 13/15 | test_acc=69.03% | test_loss=0.8818
# Round 14/15 | test_acc=69.95% | test_loss=0.8452
# Round 15/15 | test_acc=69.06% | test_loss=0.8623
#
# === alpha=0.5 | algo=FedAvgM ===
# Round 01/15 | test_acc=15.66% | test_loss=2.2969
# Round 02/15 | test_acc=24.47% | test_loss=2.2803
# Round 03/15 | test_acc=27.58% | test_loss=2.2352
# Round 04/15 | test_acc=28.53% | test_loss=2.1077
# Round 05/15 | test_acc=41.39% | test_loss=1.5726
# Round 06/15 | test_acc=10.00% | test_loss=nan
# Round 07/15 | test_acc=10.00% | test_loss=nan
# Round 08/15 | test_acc=10.00% | test_loss=nan
# Round 09/15 | test_acc=10.00% | test_loss=nan
# Round 10/15 | test_acc=10.00% | test_loss=nan
# Round 11/15 | test_acc=10.00% | test_loss=nan
# Round 12/15 | test_acc=10.00% | test_loss=nan
# Round 13/15 | test_acc=10.00% | test_loss=nan
# Round 14/15 | test_acc=10.00% | test_loss=nan
# Round 15/15 | test_acc=58.03% | test_loss=1.1603
#
# === alpha=0.5 | algo=FedLW ===
# Round 01/15 | test_acc=33.99% | test_loss=1.8307
# Round 02/15 | test_acc=46.16% | test_loss=1.4560
# Round 03/15 | test_acc=49.85% | test_loss=1.3270
# Round 04/15 | test_acc=55.65% | test_loss=1.2180
# Round 05/15 | test_acc=56.41% | test_loss=1.1672
# Round 06/15 | test_acc=61.07% | test_loss=1.0923
# Round 07/15 | test_acc=60.86% | test_loss=1.0812
# Round 08/15 | test_acc=64.06% | test_loss=1.0074
# Round 09/15 | test_acc=63.05% | test_loss=1.0214
# Round 10/15 | test_acc=65.79% | test_loss=0.9495
# Round 11/15 | test_acc=66.00% | test_loss=0.9476
# Round 12/15 | test_acc=67.42% | test_loss=0.9091
# Round 13/15 | test_acc=67.56% | test_loss=0.9154
# Round 14/15 | test_acc=68.34% | test_loss=0.8844
# Round 15/15 | test_acc=69.42% | test_loss=0.8577
#
# === alpha=0.5 | algo=FedSCAM_WA ===
# Round 01/15 | test_acc=36.44% | test_loss=1.8275
# Round 02/15 | test_acc=43.17% | test_loss=1.4844
# Round 03/15 | test_acc=48.07% | test_loss=1.3809
# Round 04/15 | test_acc=53.74% | test_loss=1.2561
# Round 05/15 | test_acc=55.85% | test_loss=1.2233
# Round 06/15 | test_acc=59.66% | test_loss=1.1033
# Round 07/15 | test_acc=61.09% | test_loss=1.0891
# Round 08/15 | test_acc=62.44% | test_loss=1.0344
# Round 09/15 | test_acc=65.00% | test_loss=0.9826
# Round 10/15 | test_acc=66.19% | test_loss=0.9438
# Round 11/15 | test_acc=66.98% | test_loss=0.9294
# Round 12/15 | test_acc=67.63% | test_loss=0.9039
# Round 13/15 | test_acc=69.31% | test_loss=0.8630
# Round 14/15 | test_acc=68.42% | test_loss=0.8783
# Round 15/15 | test_acc=70.63% | test_loss=0.8364
#
# === alpha=0.5 | algo=FedSAM ===
# Round 01/15 | test_acc=34.44% | test_loss=2.0656
# Round 02/15 | test_acc=37.81% | test_loss=1.6173
# Round 03/15 | test_acc=45.54% | test_loss=1.5074
# Round 04/15 | test_acc=45.08% | test_loss=1.4486
# Round 05/15 | test_acc=51.17% | test_loss=1.3512
# Round 06/15 | test_acc=49.58% | test_loss=1.3364
# Round 07/15 | test_acc=56.07% | test_loss=1.2481
# Round 08/15 | test_acc=54.50% | test_loss=1.2306
# Round 09/15 | test_acc=58.37% | test_loss=1.1558
# Round 10/15 | test_acc=58.63% | test_loss=1.1377
# Round 11/15 | test_acc=60.88% | test_loss=1.0941
# Round 12/15 | test_acc=60.85% | test_loss=1.0825
# Round 13/15 | test_acc=63.05% | test_loss=1.0365
# Round 14/15 | test_acc=63.36% | test_loss=1.0141
# Round 15/15 | test_acc=65.09% | test_loss=0.9828
#
# === alpha=0.5 | algo=FedLESAM ===
# Round 01/15 | test_acc=26.42% | test_loss=1.9344
# Round 02/15 | test_acc=42.92% | test_loss=1.5154
# Round 03/15 | test_acc=37.16% | test_loss=1.6920
# Round 04/15 | test_acc=43.47% | test_loss=1.5291
# Round 05/15 | test_acc=39.83% | test_loss=1.6386
# Round 06/15 | test_acc=48.12% | test_loss=1.4837
# Round 07/15 | test_acc=50.02% | test_loss=1.3541
# Round 08/15 | test_acc=56.45% | test_loss=1.2134
# Round 09/15 | test_acc=53.28% | test_loss=1.2670
# Round 10/15 | test_acc=58.05% | test_loss=1.1692
# Round 11/15 | test_acc=59.34% | test_loss=1.0998
# Round 12/15 | test_acc=64.19% | test_loss=1.0054
# Round 13/15 | test_acc=60.95% | test_loss=1.0673
# Round 14/15 | test_acc=66.21% | test_loss=0.9505
# Round 15/15 | test_acc=60.62% | test_loss=1.0570
#
# === alpha=0.5 | algo=FedWMSAM ===
# Round 01/15 | test_acc=12.90% | test_loss=2.2982
# Round 02/15 | test_acc=24.40% | test_loss=2.2837
# Round 03/15 | test_acc=23.61% | test_loss=2.2440
# Round 04/15 | test_acc=24.90% | test_loss=2.1192
# Round 05/15 | test_acc=37.37% | test_loss=1.7089
# Round 06/15 | test_acc=10.00% | test_loss=nan
# Round 07/15 | test_acc=10.00% | test_loss=nan
# Round 08/15 | test_acc=10.00% | test_loss=nan
# Round 09/15 | test_acc=10.00% | test_loss=nan
# Round 10/15 | test_acc=10.00% | test_loss=nan
# Round 11/15 | test_acc=10.00% | test_loss=nan
# Round 12/15 | test_acc=10.00% | test_loss=nan
# Round 13/15 | test_acc=10.00% | test_loss=nan
# Round 14/15 | test_acc=39.53% | test_loss=2.1814
# Round 15/15 | test_acc=50.63% | test_loss=1.3654
#
# === alpha=0.5 | algo=FedLWSAM ===
# Round 01/15 | test_acc=36.77% | test_loss=1.9953
# Round 02/15 | test_acc=39.44% | test_loss=1.5982
# Round 03/15 | test_acc=46.53% | test_loss=1.5051
# Round 04/15 | test_acc=46.22% | test_loss=1.4317
# Round 05/15 | test_acc=50.93% | test_loss=1.3588
# Round 06/15 | test_acc=51.55% | test_loss=1.3048
# Round 07/15 | test_acc=55.80% | test_loss=1.2488
# Round 08/15 | test_acc=55.63% | test_loss=1.2395
# Round 09/15 | test_acc=57.75% | test_loss=1.1706
# Round 10/15 | test_acc=59.89% | test_loss=1.1378
# Round 11/15 | test_acc=61.29% | test_loss=1.0880
# Round 12/15 | test_acc=62.24% | test_loss=1.0714
# Round 13/15 | test_acc=63.41% | test_loss=1.0328
# Round 14/15 | test_acc=64.22% | test_loss=1.0100
# Round 15/15 | test_acc=64.68% | test_loss=0.9879
#
# === alpha=0.5 | algo=FedSCAM_SAM ===
# Round 01/15 | test_acc=35.28% | test_loss=2.0099
# Round 02/15 | test_acc=39.83% | test_loss=1.5944
# Round 03/15 | test_acc=43.85% | test_loss=1.5429
# Round 04/15 | test_acc=46.53% | test_loss=1.4253
# Round 05/15 | test_acc=50.46% | test_loss=1.3753
# Round 06/15 | test_acc=50.62% | test_loss=1.3307
# Round 07/15 | test_acc=54.37% | test_loss=1.2717
# Round 08/15 | test_acc=55.76% | test_loss=1.2160
# Round 09/15 | test_acc=58.62% | test_loss=1.1555
# Round 10/15 | test_acc=58.93% | test_loss=1.1342
# Round 11/15 | test_acc=61.50% | test_loss=1.0763
# Round 12/15 | test_acc=61.98% | test_loss=1.0655
# Round 13/15 | test_acc=63.53% | test_loss=1.0187
# Round 14/15 | test_acc=63.47% | test_loss=1.0171
# Round 15/15 | test_acc=64.65% | test_loss=0.9804
#
# === alpha=0.5 | algo=FedSCAM_FULL ===
# Round 01/15 | test_acc=37.30% | test_loss=2.0015
# Round 02/15 | test_acc=39.97% | test_loss=1.5811
# Round 03/15 | test_acc=46.96% | test_loss=1.4863
# Round 04/15 | test_acc=47.39% | test_loss=1.4103
# Round 05/15 | test_acc=52.51% | test_loss=1.3331
# Round 06/15 | test_acc=51.01% | test_loss=1.3101
# Round 07/15 | test_acc=56.69% | test_loss=1.2389
# Round 08/15 | test_acc=54.98% | test_loss=1.2114
# Round 09/15 | test_acc=58.88% | test_loss=1.1676
# Round 10/15 | test_acc=58.19% | test_loss=1.1471
# Round 12/15 | test_acc=60.58% | test_loss=1.0872
# Round 13/15 | test_acc=63.82% | test_loss=1.0327
# Round 14/15 | test_acc=62.69% | test_loss=1.0411
# Round 15/15 | test_acc=65.41% | test_loss=0.9835
#
# === alpha=1.0 | algo=FedAvg ===
# Round 01/15 | test_acc=39.39% | test_loss=1.7774
# Round 02/15 | test_acc=47.95% | test_loss=1.4251
# Round 03/15 | test_acc=53.57% | test_loss=1.2861
# Round 04/15 | test_acc=55.34% | test_loss=1.2404
# Round 06/15 | test_acc=62.03% | test_loss=1.0612
# Round 07/15 | test_acc=64.10% | test_loss=1.0059
# Round 08/15 | test_acc=64.50% | test_loss=0.9853
# Round 09/15 | test_acc=66.94% | test_loss=0.9340
# Round 10/15 | test_acc=66.83% | test_loss=0.9279
# Round 11/15 | test_acc=68.75% | test_loss=0.8768
# Round 12/15 | test_acc=69.45% | test_loss=0.8557
# Round 13/15 | test_acc=69.86% | test_loss=0.8495
# Round 14/15 | test_acc=70.53% | test_loss=0.8226
# Round 15/15 | test_acc=71.16% | test_loss=0.8080
#
# === alpha=1.0 | algo=Uniform ===
# Round 01/15 | test_acc=38.14% | test_loss=1.7885
# Round 02/15 | test_acc=46.64% | test_loss=1.4674
# Round 03/15 | test_acc=50.59% | test_loss=1.3489
# Round 04/15 | test_acc=53.80% | test_loss=1.2628
# Round 05/15 | test_acc=58.32% | test_loss=1.1730
# Round 06/15 | test_acc=59.38% | test_loss=1.1218
# Round 07/15 | test_acc=55.89% | test_loss=1.2160
# Round 08/15 | test_acc=63.80% | test_loss=1.0154
# Round 09/15 | test_acc=63.75% | test_loss=1.0066
# Round 10/15 | test_acc=65.48% | test_loss=0.9646
# Round 11/15 | test_acc=67.14% | test_loss=0.9284
# Round 12/15 | test_acc=67.46% | test_loss=0.9182
# Round 13/15 | test_acc=68.88% | test_loss=0.8868
# Round 14/15 | test_acc=69.32% | test_loss=0.8743
# Round 15/15 | test_acc=69.62% | test_loss=0.8648
#
# === alpha=1.0 | algo=FedProx ===
# Round 01/15 | test_acc=37.79% | test_loss=1.7761
# Round 02/15 | test_acc=48.36% | test_loss=1.4297
# Round 03/15 | test_acc=52.79% | test_loss=1.3174
# Round 04/15 | test_acc=57.78% | test_loss=1.1964
# Round 05/15 | test_acc=59.94% | test_loss=1.1253
# Round 06/15 | test_acc=62.13% | test_loss=1.0629
# Round 07/15 | test_acc=63.76% | test_loss=1.0174
# Round 08/15 | test_acc=65.70% | test_loss=0.9719
# Round 09/15 | test_acc=66.86% | test_loss=0.9380
# Round 10/15 | test_acc=67.74% | test_loss=0.9170
# Round 11/15 | test_acc=68.69% | test_loss=0.8831
# Round 12/15 | test_acc=69.47% | test_loss=0.8624
# Round 13/15 | test_acc=70.40% | test_loss=0.8430
# Round 14/15 | test_acc=70.25% | test_loss=0.8371
# Round 15/15 | test_acc=71.59% | test_loss=0.8110
#
# === alpha=1.0 | algo=qFedAvg ===
# Round 01/15 | test_acc=40.30% | test_loss=1.7743
# Round 02/15 | test_acc=46.45% | test_loss=1.4640
# Round 03/15 | test_acc=53.00% | test_loss=1.2970
# Round 04/15 | test_acc=56.70% | test_loss=1.1913
# Round 05/15 | test_acc=59.49% | test_loss=1.1350
# Round 06/15 | test_acc=61.66% | test_loss=1.0710
# Round 07/15 | test_acc=63.38% | test_loss=1.0203
# Round 08/15 | test_acc=64.95% | test_loss=0.9897
# Round 09/15 | test_acc=66.14% | test_loss=0.9595
# Round 10/15 | test_acc=67.52% | test_loss=0.9213
# Round 11/15 | test_acc=67.80% | test_loss=0.9184
# Round 12/15 | test_acc=69.43% | test_loss=0.8721
# Round 13/15 | test_acc=68.76% | test_loss=0.8675
# Round 14/15 | test_acc=70.53% | test_loss=0.8397
# Round 15/15 | test_acc=70.16% | test_loss=0.8372
#
# === alpha=1.0 | algo=FedAvgM ===
# Round 01/15 | test_acc=12.93% | test_loss=2.2966
# Round 02/15 | test_acc=27.71% | test_loss=2.2716
# Round 03/15 | test_acc=28.15% | test_loss=2.2098
# Round 04/15 | test_acc=24.79% | test_loss=2.0749
# Round 05/15 | test_acc=45.52% | test_loss=1.4991
# Round 06/15 | test_acc=10.00% | test_loss=nan
# Round 07/15 | test_acc=10.00% | test_loss=nan
# Round 08/15 | test_acc=10.00% | test_loss=nan
# Round 09/15 | test_acc=10.00% | test_loss=nan
# Round 10/15 | test_acc=10.00% | test_loss=nan
# Round 11/15 | test_acc=10.00% | test_loss=nan
# Round 12/15 | test_acc=10.00% | test_loss=nan
# Round 13/15 | test_acc=10.00% | test_loss=nan
# Round 14/15 | test_acc=10.02% | test_loss=10.7077
# Round 15/15 | test_acc=58.90% | test_loss=1.1563
#
# === alpha=1.0 | algo=FedLW ===
# Round 01/15 | test_acc=35.91% | test_loss=1.7828
# Round 02/15 | test_acc=47.68% | test_loss=1.4208
# Round 03/15 | test_acc=53.64% | test_loss=1.2778
# Round 04/15 | test_acc=54.73% | test_loss=1.2455
# Round 05/15 | test_acc=60.24% | test_loss=1.1014
# Round 06/15 | test_acc=60.96% | test_loss=1.0971
# Round 07/15 | test_acc=63.45% | test_loss=1.0203
# Round 08/15 | test_acc=64.96% | test_loss=0.9836
# Round 09/15 | test_acc=65.55% | test_loss=0.9657
# Round 10/15 | test_acc=66.28% | test_loss=0.9448
# Round 11/15 | test_acc=67.89% | test_loss=0.9012
# Round 12/15 | test_acc=68.34% | test_loss=0.8868
# Round 13/15 | test_acc=69.81% | test_loss=0.8537
# Round 14/15 | test_acc=69.88% | test_loss=0.8460
# Round 15/15 | test_acc=70.64% | test_loss=0.8302
#
# === alpha=1.0 | algo=FedSCAM_WA ===
# Round 01/15 | test_acc=39.26% | test_loss=1.7899
# Round 02/15 | test_acc=43.41% | test_loss=1.5407
# Round 03/15 | test_acc=50.60% | test_loss=1.3456
# Round 04/15 | test_acc=54.61% | test_loss=1.2544
# Round 05/15 | test_acc=57.42% | test_loss=1.1741
# Round 06/15 | test_acc=60.21% | test_loss=1.0992
# Round 07/15 | test_acc=62.84% | test_loss=1.0433
# Round 08/15 | test_acc=64.46% | test_loss=1.0027
# Round 09/15 | test_acc=65.99% | test_loss=0.9578
# Round 10/15 | test_acc=66.71% | test_loss=0.9307
# Round 11/15 | test_acc=67.79% | test_loss=0.9059
# Round 12/15 | test_acc=68.34% | test_loss=0.8891
# Round 13/15 | test_acc=69.49% | test_loss=0.8621
# Round 14/15 | test_acc=70.18% | test_loss=0.8393
# Round 15/15 | test_acc=70.63% | test_loss=0.8280
#
# === alpha=1.0 | algo=FedSAM ===
# Round 01/15 | test_acc=36.59% | test_loss=1.9741
# Round 02/15 | test_acc=42.88% | test_loss=1.5688
# Round 03/15 | test_acc=45.81% | test_loss=1.4728
# Round 04/15 | test_acc=49.68% | test_loss=1.3749
# Round 05/15 | test_acc=50.68% | test_loss=1.3405
# Round 06/15 | test_acc=54.37% | test_loss=1.2740
# Round 07/15 | test_acc=55.83% | test_loss=1.2281
# Round 08/15 | test_acc=57.60% | test_loss=1.1742
# Round 09/15 | test_acc=59.62% | test_loss=1.1392
# Round 10/15 | test_acc=60.49% | test_loss=1.1127
# Round 11/15 | test_acc=62.18% | test_loss=1.0724
# Round 12/15 | test_acc=63.18% | test_loss=1.0374
# Round 13/15 | test_acc=64.47% | test_loss=1.0106
# Round 14/15 | test_acc=64.87% | test_loss=0.9908
# Round 15/15 | test_acc=65.40% | test_loss=0.9740
#
# === alpha=1.0 | algo=FedLESAM ===
# Round 01/15 | test_acc=31.79% | test_loss=1.8714
# Round 02/15 | test_acc=46.16% | test_loss=1.4794
# Round 03/15 | test_acc=46.67% | test_loss=1.4775
# Round 04/15 | test_acc=51.04% | test_loss=1.3171
# Round 05/15 | test_acc=51.85% | test_loss=1.3388
# Round 06/15 | test_acc=55.28% | test_loss=1.2306
# Round 07/15 | test_acc=58.23% | test_loss=1.1426
# Round 08/15 | test_acc=59.92% | test_loss=1.1197
# Round 09/15 | test_acc=63.10% | test_loss=1.0232
# Round 10/15 | test_acc=62.57% | test_loss=1.0410
# Round 11/15 | test_acc=63.20% | test_loss=1.0121
# Round 12/15 | test_acc=63.42% | test_loss=1.0071
# Round 13/15 | test_acc=66.72% | test_loss=0.9252
# Round 14/15 | test_acc=66.36% | test_loss=0.9410
# Round 15/15 | test_acc=67.68% | test_loss=0.9033
#
# === alpha=1.0 | algo=FedWMSAM ===
# Round 01/15 | test_acc=13.05% | test_loss=2.2966
# Round 02/15 | test_acc=21.35% | test_loss=2.2824
# Round 03/15 | test_acc=22.83% | test_loss=2.2425
# Round 04/15 | test_acc=25.58% | test_loss=2.1195
# Round 05/15 | test_acc=41.29% | test_loss=1.6871
# Round 06/15 | test_acc=10.00% | test_loss=nan
# Round 07/15 | test_acc=10.00% | test_loss=nan
# Round 08/15 | test_acc=10.00% | test_loss=nan
# Round 09/15 | test_acc=10.00% | test_loss=nan
# Round 10/15 | test_acc=10.00% | test_loss=nan
# Round 11/15 | test_acc=10.00% | test_loss=nan
# Round 12/15 | test_acc=10.00% | test_loss=nan
# Round 13/15 | test_acc=10.00% | test_loss=nan
# Round 14/15 | test_acc=10.00% | test_loss=7.2525
# Round 15/15 | test_acc=50.28% | test_loss=1.3664
#
# === alpha=1.0 | algo=FedLWSAM ===
# Round 01/15 | test_acc=33.60% | test_loss=1.9929
# Round 02/15 | test_acc=41.71% | test_loss=1.5904
# Round 03/15 | test_acc=46.94% | test_loss=1.4733
# Round 04/15 | test_acc=48.25% | test_loss=1.4108
# Round 05/15 | test_acc=51.77% | test_loss=1.3401
# Round 06/15 | test_acc=53.37% | test_loss=1.2822
# Round 07/15 | test_acc=54.77% | test_loss=1.2440
# Round 08/15 | test_acc=56.99% | test_loss=1.2048
# Round 09/15 | test_acc=58.63% | test_loss=1.1700
# Round 10/15 | test_acc=60.10% | test_loss=1.1269
# Round 11/15 | test_acc=60.64% | test_loss=1.1076
# Round 12/15 | test_acc=62.05% | test_loss=1.0693
# Round 13/15 | test_acc=63.05% | test_loss=1.0409
# Round 14/15 | test_acc=63.64% | test_loss=1.0236
# Round 15/15 | test_acc=64.79% | test_loss=0.9950
#
# === alpha=1.0 | algo=FedSCAM_SAM ===
# Round 01/15 | test_acc=36.33% | test_loss=1.9488
# Round 02/15 | test_acc=44.35% | test_loss=1.5635
# Round 03/15 | test_acc=46.73% | test_loss=1.4862
# Round 04/15 | test_acc=50.90% | test_loss=1.3583
# Round 05/15 | test_acc=52.13% | test_loss=1.3269
# Round 06/15 | test_acc=56.15% | test_loss=1.2374
# Round 07/15 | test_acc=56.95% | test_loss=1.1947
# Round 08/15 | test_acc=59.02% | test_loss=1.1420
# Round 09/15 | test_acc=60.71% | test_loss=1.1007
# Round 10/15 | test_acc=61.27% | test_loss=1.0801
# Round 11/15 | test_acc=63.01% | test_loss=1.0391
# Round 12/15 | test_acc=63.96% | test_loss=1.0107
# Round 13/15 | test_acc=65.56% | test_loss=0.9778
# Round 14/15 | test_acc=66.38% | test_loss=0.9594
# Round 15/15 | test_acc=66.50% | test_loss=0.9478
#
# === alpha=1.0 | algo=FedSCAM_FULL ===
# Round 01/15 | test_acc=36.69% | test_loss=1.9683
# Round 02/15 | test_acc=44.40% | test_loss=1.5425
# Round 03/15 | test_acc=47.55% | test_loss=1.4552
# Round 04/15 | test_acc=50.05% | test_loss=1.3711
# Round 05/15 | test_acc=53.24% | test_loss=1.3060
# Round 06/15 | test_acc=54.73% | test_loss=1.2599
# Round 07/15 | test_acc=56.38% | test_loss=1.2059
# Round 08/15 | test_acc=58.01% | test_loss=1.1698
# Round 09/15 | test_acc=59.58% | test_loss=1.1284
# Round 10/15 | test_acc=61.04% | test_loss=1.0990
# Round 11/15 | test_acc=61.04% | test_loss=1.0940
# Round 12/15 | test_acc=63.53% | test_loss=1.0371
# Round 13/15 | test_acc=63.69% | test_loss=1.0221
# Round 14/15 | test_acc=64.94% | test_loss=1.0007
# Round 15/15 | test_acc=65.51% | test_loss=0.9775
#     alpha          algo  final_acc  best_acc
# 0     0.1        FedAvg     0.5036    0.5036
# 11    0.1   FedSCAM_SAM     0.4877    0.4877
# 3     0.1       qFedAvg     0.4867    0.4867
# 6     0.1    FedSCAM_WA     0.4839    0.4839
# 12    0.1  FedSCAM_FULL     0.4797    0.4797
# 5     0.1         FedLW     0.4764    0.4846
# 7     0.1        FedSAM     0.4692    0.4692
# 8     0.1      FedLESAM     0.4625    0.4912
# 1     0.1       Uniform     0.4523    0.4772
# 10    0.1      FedLWSAM     0.4453    0.4767
# 2     0.1       FedProx     0.4414    0.4873
# 4     0.1       FedAvgM     0.4339    0.4339
# 9     0.1      FedWMSAM     0.3739    0.3739
# 19    0.5    FedSCAM_WA     0.7063    0.7063
# 13    0.5        FedAvg     0.6968    0.6968
# 15    0.5       FedProx     0.6948    0.7007
# 18    0.5         FedLW     0.6942    0.6942
# 16    0.5       qFedAvg     0.6906    0.6995
# 14    0.5       Uniform     0.6902    0.6902
# 25    0.5  FedSCAM_FULL     0.6541    0.6541
# 20    0.5        FedSAM     0.6509    0.6509
# 23    0.5      FedLWSAM     0.6468    0.6468
# 24    0.5   FedSCAM_SAM     0.6465    0.6465
# 21    0.5      FedLESAM     0.6062    0.6621
# 17    0.5       FedAvgM     0.5803    0.5803
# 22    0.5      FedWMSAM     0.5063    0.5063
# 28    1.0       FedProx     0.7159    0.7159
# 26    1.0        FedAvg     0.7116    0.7116
# 31    1.0         FedLW     0.7064    0.7064
# 32    1.0    FedSCAM_WA     0.7063    0.7063
# 29    1.0       qFedAvg     0.7016    0.7053
# 27    1.0       Uniform     0.6962    0.6962
# 34    1.0      FedLESAM     0.6768    0.6768
# 37    1.0   FedSCAM_SAM     0.6650    0.6650
# 38    1.0  FedSCAM_FULL     0.6551    0.6551
# 33    1.0        FedSAM     0.6540    0.6540
# 36    1.0      FedLWSAM     0.6479    0.6479
# 30    1.0       FedAvgM     0.5890    0.5890
# 35    1.0      FedWMSAM     0.5028    0.5028

# %%
WA_ALGOS = ["FedAvg","Uniform","FedProx","qFedAvg","FedAvgM","FedLW","FedSCAM_WA"]
SAM_ALGOS = ["FedSAM","FedLESAM","FedWMSAM","FedLWSAM","FedSCAM_SAM"]
FULL = ["FedSCAM_FULL"]

for alpha in cfg.alphas:
    res = all_results[alpha]

    plot_group(res, alpha, WA_ALGOS, "WA-only ablation (NO SAM): FedSCAM_WA vs weighted/WA baselines")
    plot_group(res, alpha, SAM_ALGOS, "SAM-only ablation (NO WA): FedSCAM_SAM vs SAM-family baselines")

    key = ["FedAvg","FedLW","FedSAM","FedLESAM","FedWMSAM","FedSCAM_WA","FedSCAM_SAM","FedSCAM_FULL"]
    plot_group(res, alpha, key, "Full comparison (key methods)")

# %%
# Toggle 1: FedBN off/on (can matter a lot in non-iid)
# cfg.use_fedbn = False

# Toggle 2: loss-weighting direction:
# cfg.lw_mode = "downweight_hard"  # vs "upweight_hard"

# Toggle 3: adaptive rho mode:
# cfg.adaptive_rho_mode = "loss"  # vs "grad_norm"

# Toggle 4: fixed rho to compare against adaptive rho:
# cfg.sam_rho = 0.05
# cfg.sam_rho_min = 0.05
# cfg.sam_rho_max = 0.05

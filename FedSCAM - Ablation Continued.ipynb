# %%
import os, copy, math, random, time
from dataclasses import dataclass
from typing import Dict, List, Tuple

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, Subset
import torchvision
import torchvision.transforms as T
import matplotlib.pyplot as plt
import pandas as pd

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(42)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("device:", device)
# Out:
# device: cuda

# %%
@dataclass
class CFG:
    dataset: str = "cifar10"
    num_clients: int = 10
    client_fraction: float = 1.0
    rounds: int = 15
    local_epochs: int = 1
    batch_size: int = 256
    test_batch_size: int = 512

    lr: float = 0.02
    momentum: float = 0.9
    weight_decay: float = 5e-4

    prox_mu: float = 0.001

    sam_rho: float = 0.05
    sam_rho_min: float = 0.01
    sam_rho_max: float = 0.2

    adaptive_rho_mode: str = "grad_norm"
    
    lw_mode: str = "upweight_hard"
    lw_gamma: float = 1.0 
    lw_eps: float = 1e-8

    qfed_q: float = 1.0

    server_momentum: float = 0.9

    alphas: Tuple[float, ...] = (0.1, 0.5, 1.0)

    use_fedbn: bool = True

cfg = CFG()
print(cfg)
# Out:
# CFG(dataset='cifar10', num_clients=10, client_fraction=1.0, rounds=15, local_epochs=1, batch_size=256, test_batch_size=512, lr=0.02, momentum=0.9, weight_decay=0.0005, prox_mu=0.001, sam_rho=0.05, sam_rho_min=0.01, sam_rho_max=0.2, adaptive_rho_mode='grad_norm', lw_mode='upweight_hard', lw_gamma=1.0, lw_eps=1e-08, qfed_q=1.0, server_momentum=0.9, alphas=(0.1, 0.5, 1.0), use_fedbn=True)

# %%
def get_cifar10():
    transform_train = T.Compose([
        T.RandomCrop(32, padding=4),
        T.RandomHorizontalFlip(),
        T.ToTensor(),
        T.Normalize((0.4914, 0.4822, 0.4465), (0.2470, 0.2435, 0.2616)),
    ])
    transform_test = T.Compose([
        T.ToTensor(),
        T.Normalize((0.4914, 0.4822, 0.4465), (0.2470, 0.2435, 0.2616)),
    ])
    trainset = torchvision.datasets.CIFAR10(root="./data", train=True, download=True, transform=transform_train)
    testset  = torchvision.datasets.CIFAR10(root="./data", train=False, download=True, transform=transform_test)
    return trainset, testset

trainset, testset = get_cifar10()
print("train:", len(trainset), "test:", len(testset))

test_loader = DataLoader(testset, batch_size=cfg.test_batch_size, shuffle=False, num_workers=2, pin_memory=True)

def dirichlet_partition(dataset, num_clients: int, alpha: float, num_classes: int = 10, seed: int = 42):
    rng = np.random.default_rng(seed)
    targets = np.array(dataset.targets)

    class_indices = [np.where(targets == c)[0] for c in range(num_classes)]
    for c in range(num_classes):
        rng.shuffle(class_indices[c])

    client_indices = [[] for _ in range(num_clients)]

    for c in range(num_classes):
        proportions = rng.dirichlet([alpha] * num_clients)
        proportions = proportions / proportions.sum()

        idx_c = class_indices[c]
        splits = (np.cumsum(proportions) * len(idx_c)).astype(int)[:-1]
        parts = np.split(idx_c, splits)

        for k in range(num_clients):
            client_indices[k].extend(parts[k].tolist())

    for k in range(num_clients):
        rng.shuffle(client_indices[k])

    return client_indices

def make_client_loaders(dataset, client_indices, batch_size: int, shuffle=True):
    loaders = []
    for idxs in client_indices:
        subset = Subset(dataset, idxs)
        loader = DataLoader(subset, batch_size=batch_size, shuffle=shuffle, num_workers=2, pin_memory=True, drop_last=False)
        loaders.append(loader)
    return loaders

def summarize_split(dataset, client_indices, num_classes=10):
    targets = np.array(dataset.targets)
    rows = []
    for k, idxs in enumerate(client_indices):
        y = targets[idxs]
        counts = [(y == c).sum() for c in range(num_classes)]
        rows.append([k, len(idxs)] + counts)
    cols = ["client", "n"] + [f"class_{c}" for c in range(num_classes)]
    return pd.DataFrame(rows, columns=cols)

tmp_idx = dirichlet_partition(trainset, cfg.num_clients, alpha=0.1, seed=42)
display(summarize_split(trainset, tmp_idx).head())
# Out:
# 100%|██████████| 170M/170M [00:02<00:00, 85.2MB/s]
# train: 50000 test: 10000
#    client     n  class_0  class_1  class_2  class_3  class_4  class_5  \
# 0       0  6659     2036        0        0       69     1248     2579
# 1       1  4815      226     1419       37        0      337        0
# 2       2  5554      238     1274        0        0        0        0
# 3       3  6790        0        0     1470        0       15        4
# 4       4  5327        0        1        3     2442      148      342
#
#    class_6  class_7  class_8  class_9
# 0      507      218        2        0
# 1      223       47        0     2526
# 2     4008       34        0        0
# 3      235      136     4930        0
# 4       16     1212        0     1163

# %%
class SmallCNN(nn.Module):
    def __init__(self, num_classes=10):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 32, 3, padding=1)
        self.bn1   = nn.BatchNorm2d(32)
        self.conv2 = nn.Conv2d(32, 64, 3, padding=1)
        self.bn2   = nn.BatchNorm2d(64)
        self.pool  = nn.MaxPool2d(2, 2)

        self.conv3 = nn.Conv2d(64, 128, 3, padding=1)
        self.bn3   = nn.BatchNorm2d(128)
        self.pool2 = nn.MaxPool2d(2, 2)

        self.fc1   = nn.Linear(128 * 8 * 8, 256)
        self.fc2   = nn.Linear(256, num_classes)

    def forward(self, x):
        x = self.pool(F.relu(self.bn1(self.conv1(x))))
        x = self.pool2(F.relu(self.bn2(self.conv2(x))))
        x = F.relu(self.bn3(self.conv3(x)))
        x = x.flatten(1)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

def build_model():
    return SmallCNN(num_classes=10)

loss_fn = nn.CrossEntropyLoss()

# %%
@torch.no_grad()
def evaluate(model, loader):
    model.eval()
    total, correct, total_loss = 0, 0, 0.0
    for x, y in loader:
        x, y = x.to(device), y.to(device)
        logits = model(x)
        loss = loss_fn(logits, y)
        total_loss += loss.item() * y.size(0)
        pred = logits.argmax(dim=1)
        correct += (pred == y).sum().item()
        total += y.size(0)
    return total_loss / total, correct / total

def is_bn_key(k: str) -> bool:
    return (".bn" in k) or ("bn" in k and ("running_mean" in k or "running_var" in k or "num_batches_tracked" in k))

def aggregate_state_dicts(
    global_state: Dict[str, torch.Tensor],
    client_states: List[Dict[str, torch.Tensor]],
    weights: List[float],
    use_fedbn: bool
):
    new_state = {}
    wsum = sum(weights) + 1e-12
    for k in global_state.keys():
        if use_fedbn and is_bn_key(k):
            new_state[k] = global_state[k].clone()
            continue

        acc = None
        for sd, w in zip(client_states, weights):
            t = sd[k].to(global_state[k].device)
            if acc is None:
                acc = (w / wsum) * t
            else:
                acc += (w / wsum) * t
        new_state[k] = acc
    return new_state

def sample_clients(num_clients, fraction, rng):
    m = max(1, int(round(num_clients * fraction)))
    return rng.choice(num_clients, size=m, replace=False).tolist()

# %%
def grad_norm(model: nn.Module) -> torch.Tensor:
    norms = []
    for p in model.parameters():
        if p.grad is None:
            continue
        norms.append(torch.norm(p.grad.detach(), p=2))
    if len(norms) == 0:
        return torch.tensor(0.0, device=device)
    return torch.norm(torch.stack(norms), p=2)

@torch.no_grad()
def add_scaled_grad_(model: nn.Module, scale: float):
    for p in model.parameters():
        if p.grad is None:
            continue
        p.add_(p.grad, alpha=scale)

@torch.no_grad()
def save_params(model: nn.Module):
    return [p.detach().clone() for p in model.parameters()]

@torch.no_grad()
def load_params(model: nn.Module, params_backup):
    for p, b in zip(model.parameters(), params_backup):
        p.copy_(b)

def sam_batch_update(model, optimizer, x, y, rho: float):
    model.train()
    optimizer.zero_grad(set_to_none=True)
    logits = model(x)
    loss = loss_fn(logits, y)
    loss.backward()

    gnorm = grad_norm(model)
    scale = rho / (gnorm + 1e-12)

    backup = save_params(model)
    add_scaled_grad_(model, scale)

    optimizer.zero_grad(set_to_none=True)
    logits2 = model(x)
    loss2 = loss_fn(logits2, y)
    loss2.backward()

    load_params(model, backup)
    optimizer.step()

    return loss.item(), loss2.item(), gnorm.item()

# %%
def make_optimizer(model):
    return torch.optim.SGD(model.parameters(), lr=cfg.lr, momentum=cfg.momentum, weight_decay=cfg.weight_decay)

def local_train_sgd(model, loader, epochs=1):
    model.train()
    opt = make_optimizer(model)
    total_loss, total_n = 0.0, 0
    for _ in range(epochs):
        for x, y in loader:
            x, y = x.to(device), y.to(device)
            opt.zero_grad(set_to_none=True)
            logits = model(x)
            loss = loss_fn(logits, y)
            loss.backward()
            opt.step()
            total_loss += loss.item() * y.size(0)
            total_n += y.size(0)
    return total_loss / max(1, total_n)

def local_train_fedprox(model, global_model, loader, epochs=1, mu=0.001):
    model.train()
    opt = make_optimizer(model)
    g_params = [p.detach().clone() for p in global_model.parameters()]
    total_loss, total_n = 0.0, 0

    for _ in range(epochs):
        for x, y in loader:
            x, y = x.to(device), y.to(device)
            opt.zero_grad(set_to_none=True)
            logits = model(x)
            loss = loss_fn(logits, y)

            prox = 0.0
            for p, gp in zip(model.parameters(), g_params):
                prox = prox + (p - gp).pow(2).sum()
            loss = loss + (mu / 2.0) * prox

            loss.backward()
            opt.step()

            total_loss += loss.item() * y.size(0)
            total_n += y.size(0)

    return total_loss / max(1, total_n)

def local_train_fedsam(model, loader, epochs=1, rho=0.05):
    opt = make_optimizer(model)
    total_loss, total_n = 0.0, 0
    for _ in range(epochs):
        for x, y in loader:
            x, y = x.to(device), y.to(device)
            l1, l2, _ = sam_batch_update(model, opt, x, y, rho=rho)
            total_loss += l2 * y.size(0)
            total_n += y.size(0)
    return total_loss / max(1, total_n)

def compute_adaptive_rho(client_stat: float, ref_stat: float, rho0: float, rho_min: float, rho_max: float):
    ratio = client_stat / (ref_stat + 1e-12)
    rho = rho0 * ratio
    return float(np.clip(rho, rho_min, rho_max))

@torch.no_grad()
def get_one_batch(loader):
    for x, y in loader:
        return x.to(device), y.to(device)
    raise RuntimeError("empty loader")

def client_probe_stats(model, loader):
    model.train()
    x, y = get_one_batch(loader)
    for p in model.parameters():
        if p.grad is not None:
            p.grad = None
    logits = model(x)
    loss = loss_fn(logits, y)
    loss.backward()
    gn = grad_norm(model).item()
    return loss.item(), gn

def local_train_adaptive_sam(model, loader, epochs, rho_for_client: float):
    opt = make_optimizer(model)
    total_loss, total_n = 0.0, 0
    for _ in range(epochs):
        for x, y in loader:
            x, y = x.to(device), y.to(device)
            _, l2, _ = sam_batch_update(model, opt, x, y, rho=rho_for_client)
            total_loss += l2 * y.size(0)
            total_n += y.size(0)
    return total_loss / max(1, total_n)

@torch.no_grad()
def apply_global_perturbation(model, direction_state, rho):
    for name, p in model.named_parameters():
        if name in direction_state:
            d = direction_state[name].to(p.device)
            p.add_(d, alpha=rho)

@torch.no_grad()
def remove_global_perturbation(model, direction_state, rho):
    for name, p in model.named_parameters():
        if name in direction_state:
            d = direction_state[name].to(p.device)
            p.add_(d, alpha=-rho)

def normalize_direction_state(direction_state):
    sq = 0.0
    for v in direction_state.values():
        sq += (v.detach().float().norm(p=2) ** 2).item()
    norm = math.sqrt(sq) + 1e-12
    out = {k: (v / norm) for k, v in direction_state.items()}
    return out, norm

def local_train_lesam(model, loader, epochs, global_direction_state, rho):
    opt = make_optimizer(model)
    total_loss, total_n = 0.0, 0

    for _ in range(epochs):
        for x, y in loader:
            x, y = x.to(device), y.to(device)

            apply_global_perturbation(model, global_direction_state, rho)

            opt.zero_grad(set_to_none=True)
            logits = model(x)
            loss = loss_fn(logits, y)
            loss.backward()

            remove_global_perturbation(model, global_direction_state, rho)
            opt.step()

            total_loss += loss.item() * y.size(0)
            total_n += y.size(0)

    return total_loss / max(1, total_n)

# %%
def weights_fedavg(client_sizes):
    return [float(n) for n in client_sizes]

def weights_uniform(num_clients):
    return [1.0] * num_clients

def weights_fedlw(client_sizes, client_losses, mode="upweight_hard", gamma=1.0, eps=1e-8):
    ws = []
    for n, l in zip(client_sizes, client_losses):
        if mode == "upweight_hard":
            ws.append(float(n) * float((l + eps) ** gamma))
        else:
            ws.append(float(n) / float((l + eps) ** gamma))
    return ws

def weights_qfedavg(client_sizes, client_losses, q=1.0, eps=1e-8):
    return [float(n) * float((l + eps) ** q) for n, l in zip(client_sizes, client_losses)]

# %%
def state_dict_to_cpu(sd):
    return {k: v.detach().cpu().clone() for k, v in sd.items()}

def run_one_alpha(alpha: float, seed: int = 42):
    rng = np.random.default_rng(seed)

    client_indices = dirichlet_partition(trainset, cfg.num_clients, alpha=alpha, seed=seed)
    client_loaders = make_client_loaders(trainset, client_indices, batch_size=cfg.batch_size, shuffle=True)

    client_sizes = [len(idxs) for idxs in client_indices]
    WA_ALGOS = [
        "FedAvg",
        "Uniform",
        "FedProx",
        "qFedAvg",
        "FedAvgM",       
        "FedLW",       
        "FedSCAM_WA",   
    ]

    SAM_ALGOS = [
        "FedSAM",
        "FedLESAM",
        "FedWMSAM",     
        "FedLWSAM",  
        "FedSCAM_SAM",   
    ]

    FULL_ALGOS = ["FedSCAM_FULL"]

    ALL_ALGOS = WA_ALGOS + SAM_ALGOS + FULL_ALGOS

    results = {algo: {"acc": [], "loss": []} for algo in ALL_ALGOS}

    server_momentum_buffers = {algo: None for algo in ALL_ALGOS}

    for algo in ALL_ALGOS:
        global_model = build_model().to(device)
        global_state = copy.deepcopy(global_model.state_dict())

        server_m = None 
        if algo in ["FedAvgM", "FedWMSAM"] or "AvgM" in algo:
            server_m = {k: torch.zeros_like(v) for k, v in global_state.items()}

        print(f"\n=== alpha={alpha} | algo={algo} ===")
        for r in range(1, cfg.rounds + 1):
            selected = sample_clients(cfg.num_clients, cfg.client_fraction, rng)

            probe_losses = []
            probe_gns = []
            probe_grads = [] 

            if algo in ["FedSCAM_SAM", "FedSCAM_FULL", "FedLESAM"]:
                for k in selected:
                    m = build_model().to(device)
                    m.load_state_dict(global_state)
                    l, gn = client_probe_stats(m, client_loaders[k])
                    probe_losses.append(l)
                    probe_gns.append(gn)

                    if algo == "FedLESAM":
                        gstate = {}
                        for name, p in m.named_parameters():
                            if p.grad is None:
                                continue
                            gstate[name] = p.grad.detach().clone()
                        probe_grads.append(gstate)

                ref_loss = float(np.mean(probe_losses)) if len(probe_losses) else 1.0
                ref_gn   = float(np.mean(probe_gns)) if len(probe_gns) else 1.0

                if algo == "FedLESAM":
                    avg_g = {}
                    for gstate in probe_grads:
                        for name, g in gstate.items():
                            if name not in avg_g:
                                avg_g[name] = g.detach().clone()
                            else:
                                avg_g[name] += g.detach().clone()
                    for name in avg_g:
                        avg_g[name] /= max(1, len(probe_grads))
                    avg_g, _ = normalize_direction_state(avg_g)
                else:
                    avg_g = None
            else:
                ref_loss, ref_gn, avg_g = None, None, None

            client_states = []
            client_train_losses = []
            selected_sizes = []

            for k in selected:
                local_model = build_model().to(device)
                local_model.load_state_dict(global_state)

                if algo in ["FedAvg", "Uniform", "FedLW", "FedSCAM_WA", "qFedAvg", "FedAvgM"]:
                    if algo == "FedProx":
                        raise RuntimeError("FedProx handled below")
                    tr_loss = local_train_sgd(local_model, client_loaders[k], epochs=cfg.local_epochs)

                elif algo == "FedProx":
                    gmodel = build_model().to(device)
                    gmodel.load_state_dict(global_state)
                    tr_loss = local_train_fedprox(local_model, gmodel, client_loaders[k],
                                                  epochs=cfg.local_epochs, mu=cfg.prox_mu)

                elif algo in ["FedSAM", "FedWMSAM", "FedLWSAM"]:
                    tr_loss = local_train_fedsam(local_model, client_loaders[k],
                                                 epochs=cfg.local_epochs, rho=cfg.sam_rho)

                elif algo in ["FedSCAM_SAM", "FedSCAM_FULL"]:
                    if cfg.adaptive_rho_mode == "loss":
                        idx = selected.index(k)
                        stat = probe_losses[idx]
                        ref  = ref_loss
                    else:
                        idx = selected.index(k)
                        stat = probe_gns[idx]
                        ref  = ref_gn

                    rho_k = compute_adaptive_rho(stat, ref, cfg.sam_rho, cfg.sam_rho_min, cfg.sam_rho_max)
                    tr_loss = local_train_adaptive_sam(local_model, client_loaders[k],
                                                       epochs=cfg.local_epochs, rho_for_client=rho_k)

                elif algo == "FedLESAM":
                    tr_loss = local_train_lesam(local_model, client_loaders[k],
                                                epochs=cfg.local_epochs,
                                                global_direction_state=avg_g,
                                                rho=cfg.sam_rho)

                elif algo == "FedSCAM_FULL":
                    raise RuntimeError("FedSCAM_FULL handled above")

                else:
                    raise ValueError(f"Unknown algo: {algo}")

                client_states.append(copy.deepcopy(local_model.state_dict()))
                client_train_losses.append(float(tr_loss))
                selected_sizes.append(client_sizes[k])

            if algo == "FedAvg":
                agg_w = weights_fedavg(selected_sizes)
            elif algo == "Uniform":
                agg_w = weights_uniform(len(selected))
            elif algo == "FedProx":
                agg_w = weights_fedavg(selected_sizes)
            elif algo == "qFedAvg":
                agg_w = weights_qfedavg(selected_sizes, client_train_losses, q=cfg.qfed_q, eps=cfg.lw_eps)
            elif algo == "FedAvgM":
                agg_w = weights_fedavg(selected_sizes)
            elif algo == "FedLW":
                agg_w = weights_fedlw(selected_sizes, client_train_losses, mode=cfg.lw_mode,
                                      gamma=cfg.lw_gamma, eps=cfg.lw_eps)
            elif algo == "FedSCAM_WA":
                agg_w = weights_fedlw(selected_sizes, client_train_losses, mode=cfg.lw_mode,
                                      gamma=cfg.lw_gamma, eps=cfg.lw_eps)
            elif algo == "FedSAM":
                agg_w = weights_fedavg(selected_sizes)
            elif algo == "FedLESAM":
                agg_w = weights_fedavg(selected_sizes)
            elif algo == "FedWMSAM":
                agg_w = weights_fedavg(selected_sizes)
            elif algo == "FedLWSAM":
                agg_w = weights_fedlw(selected_sizes, client_train_losses, mode=cfg.lw_mode,
                                      gamma=cfg.lw_gamma, eps=cfg.lw_eps)
            elif algo == "FedSCAM_SAM":
                agg_w = weights_fedavg(selected_sizes)
            elif algo == "FedSCAM_FULL":
                agg_w = weights_fedlw(selected_sizes, client_train_losses, mode=cfg.lw_mode,
                                      gamma=cfg.lw_gamma, eps=cfg.lw_eps)
            else:
                agg_w = weights_fedavg(selected_sizes)

            if algo in ["FedAvgM", "FedWMSAM"]:
                new_avg_state = aggregate_state_dicts(global_state, client_states, agg_w, use_fedbn=cfg.use_fedbn)
                delta = {k: (new_avg_state[k] - global_state[k]) for k in global_state.keys()}

                beta = cfg.server_momentum
                for k in server_m:
                    server_m[k] = beta * server_m[k] + (1.0 - beta) * delta[k]

                global_state = {k: (global_state[k] + server_m[k]) for k in global_state.keys()}
            else:
                global_state = aggregate_state_dicts(global_state, client_states, agg_w, use_fedbn=cfg.use_fedbn)

            global_model.load_state_dict(global_state)
            te_loss, te_acc = evaluate(global_model, test_loader)
            results[algo]["acc"].append(te_acc)
            results[algo]["loss"].append(te_loss)

            print(f"Round {r:02d}/{cfg.rounds} | test_acc={te_acc*100:.2f}% | test_loss={te_loss:.4f}")

    return results

def plot_group(results_alpha, alpha, algos, title):
    plt.figure(figsize=(10, 5))
    for a in algos:
        plt.plot(np.arange(1, cfg.rounds+1), results_alpha[a]["acc"], label=a)
    plt.xlabel("Round")
    plt.ylabel("Test Accuracy")
    plt.title(f"{title} | alpha={alpha}")
    plt.grid(True)
    plt.legend()
    plt.show()

def final_table(all_results):
    rows = []
    for alpha, res in all_results.items():
        for algo, vals in res.items():
            rows.append({
                "alpha": alpha,
                "algo": algo,
                "final_acc": vals["acc"][-1],
                "best_acc": max(vals["acc"]),
            })
    df = pd.DataFrame(rows).sort_values(["alpha", "final_acc"], ascending=[True, False])
    return df

all_results = {}
for a in cfg.alphas:
    all_results[a] = run_one_alpha(alpha=a, seed=42)

df = final_table(all_results)
display(df)
# Out:
# === alpha=0.1 | algo=FedAvg ===
# Round 01/15 | test_acc=9.64% | test_loss=2.2990
# Round 02/15 | test_acc=10.40% | test_loss=2.2829
# Round 03/15 | test_acc=11.29% | test_loss=2.2817
# Round 04/15 | test_acc=15.27% | test_loss=2.2779
# Round 05/15 | test_acc=12.55% | test_loss=2.2725
# Round 06/15 | test_acc=14.32% | test_loss=2.2726
# Round 07/15 | test_acc=18.02% | test_loss=2.2670
# Round 08/15 | test_acc=16.50% | test_loss=2.2739
# Round 09/15 | test_acc=19.49% | test_loss=2.2647
# Round 10/15 | test_acc=13.43% | test_loss=2.2739
# Round 11/15 | test_acc=21.58% | test_loss=2.2671
# Round 12/15 | test_acc=14.94% | test_loss=2.2781
# Round 13/15 | test_acc=19.91% | test_loss=2.2639
# Round 14/15 | test_acc=16.39% | test_loss=2.2811
# Round 15/15 | test_acc=17.84% | test_loss=2.2691
#
# === alpha=0.1 | algo=Uniform ===
# Round 01/15 | test_acc=18.38% | test_loss=2.2920
# Round 02/15 | test_acc=21.11% | test_loss=2.2829
# Round 03/15 | test_acc=16.98% | test_loss=2.2691
# Round 04/15 | test_acc=22.45% | test_loss=2.2605
# Round 05/15 | test_acc=17.93% | test_loss=2.2522
# Round 06/15 | test_acc=21.14% | test_loss=2.2566
# Round 07/15 | test_acc=19.59% | test_loss=2.2415
# Round 08/15 | test_acc=22.25% | test_loss=2.2583
# Round 09/15 | test_acc=21.17% | test_loss=2.2429
# Round 10/15 | test_acc=23.35% | test_loss=2.2505
# Round 11/15 | test_acc=22.76% | test_loss=2.2251
# Round 12/15 | test_acc=17.88% | test_loss=2.2605
# Round 13/15 | test_acc=25.59% | test_loss=2.2270
# Round 14/15 | test_acc=23.29% | test_loss=2.2457
# Round 15/15 | test_acc=24.42% | test_loss=2.2238
#
# === alpha=0.1 | algo=FedProx ===
# Round 01/15 | test_acc=11.98% | test_loss=2.2969
# Round 02/15 | test_acc=11.95% | test_loss=2.2813
# Round 03/15 | test_acc=18.10% | test_loss=2.2792
# Round 04/15 | test_acc=16.76% | test_loss=2.2662
# Round 05/15 | test_acc=17.30% | test_loss=2.2793
# Round 06/15 | test_acc=20.91% | test_loss=2.2519
# Round 07/15 | test_acc=27.26% | test_loss=2.2657
# Round 08/15 | test_acc=21.10% | test_loss=2.2585
# Round 09/15 | test_acc=27.18% | test_loss=2.2619
# Round 10/15 | test_acc=22.79% | test_loss=2.2497
# Round 11/15 | test_acc=20.69% | test_loss=2.2650
# Round 12/15 | test_acc=25.66% | test_loss=2.2384
# Round 13/15 | test_acc=20.08% | test_loss=2.2757
# Round 14/15 | test_acc=24.51% | test_loss=2.2495
# Round 15/15 | test_acc=23.17% | test_loss=2.2623
#
# === alpha=0.1 | algo=qFedAvg ===
# Round 01/15 | test_acc=13.68% | test_loss=2.2986
# Round 02/15 | test_acc=13.62% | test_loss=2.2860
# Round 03/15 | test_acc=19.42% | test_loss=2.2829
# Round 04/15 | test_acc=18.53% | test_loss=2.2670
# Round 05/15 | test_acc=15.57% | test_loss=2.2826
# Round 06/15 | test_acc=23.04% | test_loss=2.2637
# Round 07/15 | test_acc=17.40% | test_loss=2.2803
# Round 08/15 | test_acc=24.25% | test_loss=2.2531
# Round 09/15 | test_acc=16.78% | test_loss=2.2748
# Round 10/15 | test_acc=21.00% | test_loss=2.2456
# Round 11/15 | test_acc=18.70% | test_loss=2.2734
# Round 12/15 | test_acc=20.46% | test_loss=2.2502
# Round 13/15 | test_acc=15.68% | test_loss=2.2660
# Round 14/15 | test_acc=17.58% | test_loss=2.2584
# Round 15/15 | test_acc=18.25% | test_loss=2.2608
#
# === alpha=0.1 | algo=FedAvgM ===
# Round 01/15 | test_acc=10.56% | test_loss=2.3014
# Round 02/15 | test_acc=10.13% | test_loss=2.3008
# Round 03/15 | test_acc=10.10% | test_loss=2.2989
# Round 04/15 | test_acc=12.47% | test_loss=2.2953
# Round 05/15 | test_acc=20.57% | test_loss=2.2891
# Round 06/15 | test_acc=19.88% | test_loss=2.2800
# Round 07/15 | test_acc=17.71% | test_loss=2.2692
# Round 08/15 | test_acc=17.36% | test_loss=2.2588
# Round 09/15 | test_acc=17.63% | test_loss=2.2497
# Round 10/15 | test_acc=18.54% | test_loss=2.2427
# Round 11/15 | test_acc=19.14% | test_loss=2.2382
# Round 12/15 | test_acc=19.53% | test_loss=2.2351
# Round 13/15 | test_acc=19.94% | test_loss=2.2335
# Round 14/15 | test_acc=20.86% | test_loss=2.2323
# Round 15/15 | test_acc=22.00% | test_loss=2.2319
#
# === alpha=0.1 | algo=FedLW ===
# Round 01/15 | test_acc=10.00% | test_loss=2.3019
# Round 02/15 | test_acc=12.26% | test_loss=2.2939
# Round 03/15 | test_acc=16.79% | test_loss=2.2818
# Round 04/15 | test_acc=20.35% | test_loss=2.2788
# Round 05/15 | test_acc=12.87% | test_loss=2.2731
# Round 06/15 | test_acc=18.28% | test_loss=2.2730
# Round 07/15 | test_acc=14.17% | test_loss=2.2693
# Round 08/15 | test_acc=20.09% | test_loss=2.2736
# Round 09/15 | test_acc=12.99% | test_loss=2.2562
# Round 10/15 | test_acc=16.09% | test_loss=2.2777
# Round 11/15 | test_acc=12.21% | test_loss=2.2629
# Round 12/15 | test_acc=11.08% | test_loss=2.2714
# Round 13/15 | test_acc=12.16% | test_loss=2.2624
# Round 14/15 | test_acc=12.26% | test_loss=2.2720
# Round 15/15 | test_acc=15.28% | test_loss=2.2666
#
# === alpha=0.1 | algo=FedSCAM_WA ===
# Round 01/15 | test_acc=14.93% | test_loss=2.2987
# Round 02/15 | test_acc=13.56% | test_loss=2.2859
# Round 03/15 | test_acc=15.06% | test_loss=2.2797
# Round 04/15 | test_acc=17.16% | test_loss=2.2700
# Round 05/15 | test_acc=17.84% | test_loss=2.2623
# Round 06/15 | test_acc=22.00% | test_loss=2.2593
# Round 07/15 | test_acc=20.78% | test_loss=2.2581
# Round 08/15 | test_acc=19.28% | test_loss=2.2413
# Round 09/15 | test_acc=17.58% | test_loss=2.2664
# Round 10/15 | test_acc=17.37% | test_loss=2.2393
# Round 11/15 | test_acc=20.36% | test_loss=2.2576
# Round 12/15 | test_acc=17.51% | test_loss=2.2307
# Round 13/15 | test_acc=21.01% | test_loss=2.2583
# Round 14/15 | test_acc=20.76% | test_loss=2.2339
# Round 15/15 | test_acc=21.27% | test_loss=2.2507
#
# === alpha=0.1 | algo=FedSAM ===
# Round 01/15 | test_acc=14.90% | test_loss=2.3013
# Round 02/15 | test_acc=12.46% | test_loss=2.2899
# Round 03/15 | test_acc=18.28% | test_loss=2.2825
# Round 04/15 | test_acc=19.09% | test_loss=2.2771
# Round 05/15 | test_acc=14.75% | test_loss=2.2643
# Round 06/15 | test_acc=19.37% | test_loss=2.2499
# Round 07/15 | test_acc=22.77% | test_loss=2.2503
# Round 08/15 | test_acc=21.98% | test_loss=2.2464
# Round 09/15 | test_acc=21.46% | test_loss=2.2422
# Round 10/15 | test_acc=24.12% | test_loss=2.2294
# Round 11/15 | test_acc=21.21% | test_loss=2.2372
# Round 12/15 | test_acc=22.83% | test_loss=2.2317
# Round 13/15 | test_acc=23.73% | test_loss=2.2230
# Round 14/15 | test_acc=22.05% | test_loss=2.2368
# Round 15/15 | test_acc=22.52% | test_loss=2.2240
#
# === alpha=0.1 | algo=FedLESAM ===
# Round 01/15 | test_acc=16.40% | test_loss=2.2951
# Round 02/15 | test_acc=21.33% | test_loss=2.2786
# Round 03/15 | test_acc=13.13% | test_loss=2.2874
# Round 04/15 | test_acc=23.03% | test_loss=2.2693
# Round 05/15 | test_acc=13.57% | test_loss=2.2846
# Round 06/15 | test_acc=22.55% | test_loss=2.2617
# Round 07/15 | test_acc=10.45% | test_loss=2.2922
# Round 08/15 | test_acc=22.83% | test_loss=2.2550
# Round 09/15 | test_acc=15.58% | test_loss=2.2716
# Round 10/15 | test_acc=23.67% | test_loss=2.2594
# Round 11/15 | test_acc=14.63% | test_loss=2.2687
# Round 12/15 | test_acc=21.97% | test_loss=2.2621
# Round 13/15 | test_acc=13.74% | test_loss=2.2681
# Round 14/15 | test_acc=21.27% | test_loss=2.2552
# Round 15/15 | test_acc=12.83% | test_loss=2.2703
#
# === alpha=0.1 | algo=FedWMSAM ===
# Round 01/15 | test_acc=10.66% | test_loss=2.3019
# Round 02/15 | test_acc=10.00% | test_loss=2.3020
# Round 03/15 | test_acc=10.00% | test_loss=2.3011
# Round 04/15 | test_acc=10.90% | test_loss=2.2988
# Round 05/15 | test_acc=13.40% | test_loss=2.2947
# Round 06/15 | test_acc=17.45% | test_loss=2.2883
# Round 07/15 | test_acc=20.23% | test_loss=2.2798
# Round 08/15 | test_acc=19.78% | test_loss=2.2697
# Round 09/15 | test_acc=18.41% | test_loss=2.2591
# Round 10/15 | test_acc=19.00% | test_loss=2.2492
# Round 11/15 | test_acc=20.58% | test_loss=2.2414
# Round 12/15 | test_acc=21.29% | test_loss=2.2363
# Round 13/15 | test_acc=21.60% | test_loss=2.2329
# Round 14/15 | test_acc=21.72% | test_loss=2.2301
# Round 15/15 | test_acc=21.28% | test_loss=2.2275
#
# === alpha=0.1 | algo=FedLWSAM ===
# Round 01/15 | test_acc=9.99% | test_loss=2.3029
# Round 02/15 | test_acc=19.06% | test_loss=2.2936
# Round 03/15 | test_acc=10.18% | test_loss=2.2885
# Round 04/15 | test_acc=16.84% | test_loss=2.2868
# Round 05/15 | test_acc=20.10% | test_loss=2.2791
# Round 06/15 | test_acc=23.20% | test_loss=2.2663
# Round 07/15 | test_acc=21.98% | test_loss=2.2686
# Round 08/15 | test_acc=25.09% | test_loss=2.2580
# Round 09/15 | test_acc=16.68% | test_loss=2.2556
# Round 10/15 | test_acc=22.43% | test_loss=2.2508
# Round 11/15 | test_acc=16.84% | test_loss=2.2454
# Round 12/15 | test_acc=22.54% | test_loss=2.2429
# Round 13/15 | test_acc=17.95% | test_loss=2.2444
# Round 14/15 | test_acc=22.05% | test_loss=2.2475
# Round 15/15 | test_acc=18.03% | test_loss=2.2410
#
# === alpha=0.1 | algo=FedSCAM_SAM ===
# Round 01/15 | test_acc=9.30% | test_loss=2.3013
# Round 02/15 | test_acc=9.63% | test_loss=2.2913
# Round 03/15 | test_acc=10.90% | test_loss=2.2835
# Round 04/15 | test_acc=11.81% | test_loss=2.2699
# Round 05/15 | test_acc=13.07% | test_loss=2.2701
# Round 06/15 | test_acc=16.88% | test_loss=2.2499
# Round 07/15 | test_acc=18.27% | test_loss=2.2533
# Round 08/15 | test_acc=17.41% | test_loss=2.2470
# Round 09/15 | test_acc=20.16% | test_loss=2.2462
# Round 10/15 | test_acc=20.18% | test_loss=2.2359
# Round 11/15 | test_acc=17.22% | test_loss=2.2450
# Round 12/15 | test_acc=19.36% | test_loss=2.2330
# Round 13/15 | test_acc=16.53% | test_loss=2.2325
# Round 14/15 | test_acc=19.93% | test_loss=2.2284
# Round 15/15 | test_acc=16.23% | test_loss=2.2360
#
# === alpha=0.1 | algo=FedSCAM_FULL ===
# Round 01/15 | test_acc=10.00% | test_loss=2.3025
# Round 02/15 | test_acc=14.87% | test_loss=2.2895
# Round 03/15 | test_acc=15.54% | test_loss=2.2872
# Round 04/15 | test_acc=16.29% | test_loss=2.2725
# Round 05/15 | test_acc=12.76% | test_loss=2.2669
# Round 06/15 | test_acc=12.47% | test_loss=2.2573
# Round 07/15 | test_acc=12.11% | test_loss=2.2620
# Round 08/15 | test_acc=14.00% | test_loss=2.2476
# Round 09/15 | test_acc=14.75% | test_loss=2.2612
# Round 10/15 | test_acc=15.09% | test_loss=2.2405
# Round 11/15 | test_acc=12.32% | test_loss=2.2471
# Round 12/15 | test_acc=18.12% | test_loss=2.2410
# Round 13/15 | test_acc=13.36% | test_loss=2.2397
# Round 14/15 | test_acc=21.59% | test_loss=2.2295
# Round 15/15 | test_acc=14.48% | test_loss=2.2443
#
# === alpha=0.5 | algo=FedAvg ===
# Round 01/15 | test_acc=13.04% | test_loss=2.2778
# Round 02/15 | test_acc=16.09% | test_loss=2.2458
# Round 03/15 | test_acc=22.33% | test_loss=2.2386
# Round 04/15 | test_acc=30.44% | test_loss=2.2346
# Round 05/15 | test_acc=28.19% | test_loss=2.2334
# Round 06/15 | test_acc=31.36% | test_loss=2.2300
# Round 07/15 | test_acc=28.97% | test_loss=2.2361
# Round 08/15 | test_acc=31.50% | test_loss=2.2278
# Round 09/15 | test_acc=32.56% | test_loss=2.2206
# Round 10/15 | test_acc=32.06% | test_loss=2.2131
# Round 11/15 | test_acc=32.19% | test_loss=2.2254
# Round 12/15 | test_acc=31.37% | test_loss=2.2075
# Round 13/15 | test_acc=33.10% | test_loss=2.2106
# Round 14/15 | test_acc=32.70% | test_loss=2.2097
# Round 15/15 | test_acc=28.59% | test_loss=2.2153
#
# === alpha=0.5 | algo=Uniform ===
# Round 01/15 | test_acc=11.30% | test_loss=2.2824
# Round 02/15 | test_acc=16.42% | test_loss=2.2512
# Round 03/15 | test_acc=18.21% | test_loss=2.2553
# Round 04/15 | test_acc=24.98% | test_loss=2.2380
# Round 05/15 | test_acc=25.15% | test_loss=2.2439
# Round 06/15 | test_acc=27.64% | test_loss=2.2361
# Round 07/15 | test_acc=25.36% | test_loss=2.2308
# Round 08/15 | test_acc=28.01% | test_loss=2.2306
# Round 09/15 | test_acc=25.19% | test_loss=2.2190
# Round 10/15 | test_acc=28.79% | test_loss=2.2202
# Round 11/15 | test_acc=25.87% | test_loss=2.2162
# Round 12/15 | test_acc=30.18% | test_loss=2.2175
# Round 13/15 | test_acc=30.01% | test_loss=2.2107
# Round 14/15 | test_acc=30.87% | test_loss=2.2089
# Round 15/15 | test_acc=34.00% | test_loss=2.1984
#
# === alpha=0.5 | algo=FedProx ===
# Round 01/15 | test_acc=10.03% | test_loss=2.2792
# Round 02/15 | test_acc=15.35% | test_loss=2.2503
# Round 03/15 | test_acc=19.93% | test_loss=2.2602
# Round 04/15 | test_acc=19.89% | test_loss=2.2400
# Round 05/15 | test_acc=28.54% | test_loss=2.2402
# Round 06/15 | test_acc=28.77% | test_loss=2.2310
# Round 07/15 | test_acc=33.48% | test_loss=2.2383
# Round 08/15 | test_acc=29.98% | test_loss=2.2240
# Round 09/15 | test_acc=34.78% | test_loss=2.2266
# Round 10/15 | test_acc=30.39% | test_loss=2.2173
# Round 11/15 | test_acc=35.00% | test_loss=2.2175
# Round 12/15 | test_acc=32.23% | test_loss=2.2027
# Round 13/15 | test_acc=36.23% | test_loss=2.2037
# Round 14/15 | test_acc=35.04% | test_loss=2.2019
# Round 15/15 | test_acc=34.09% | test_loss=2.2031
#
# === alpha=0.5 | algo=qFedAvg ===
# Round 01/15 | test_acc=10.05% | test_loss=2.2736
# Round 02/15 | test_acc=12.00% | test_loss=2.2523
# Round 03/15 | test_acc=16.40% | test_loss=2.2420
# Round 04/15 | test_acc=18.35% | test_loss=2.2396
# Round 05/15 | test_acc=28.63% | test_loss=2.2327
# Round 06/15 | test_acc=24.25% | test_loss=2.2273
# Round 07/15 | test_acc=31.00% | test_loss=2.2165
# Round 08/15 | test_acc=29.65% | test_loss=2.2200
# Round 09/15 | test_acc=30.20% | test_loss=2.2167
# Round 10/15 | test_acc=33.03% | test_loss=2.2061
# Round 11/15 | test_acc=31.71% | test_loss=2.1983
# Round 12/15 | test_acc=30.08% | test_loss=2.2059
# Round 13/15 | test_acc=33.15% | test_loss=2.1879
# Round 14/15 | test_acc=32.86% | test_loss=2.1947
# Round 15/15 | test_acc=31.82% | test_loss=2.1906
#
# === alpha=0.5 | algo=FedAvgM ===
# Round 01/15 | test_acc=14.97% | test_loss=2.2993
# Round 02/15 | test_acc=15.12% | test_loss=2.2947
# Round 03/15 | test_acc=14.51% | test_loss=2.2887
# Round 04/15 | test_acc=14.59% | test_loss=2.2808
# Round 05/15 | test_acc=16.32% | test_loss=2.2717
# Round 06/15 | test_acc=17.83% | test_loss=2.2625
# Round 07/15 | test_acc=18.13% | test_loss=2.2529
# Round 08/15 | test_acc=18.76% | test_loss=2.2436
# Round 09/15 | test_acc=19.55% | test_loss=2.2343
# Round 10/15 | test_acc=20.45% | test_loss=2.2252
# Round 11/15 | test_acc=21.52% | test_loss=2.2166
# Round 12/15 | test_acc=22.63% | test_loss=2.2083
# Round 13/15 | test_acc=23.75% | test_loss=2.2016
# Round 14/15 | test_acc=24.24% | test_loss=2.1972
# Round 15/15 | test_acc=24.50% | test_loss=2.1944
#
# === alpha=0.5 | algo=FedLW ===
# Round 01/15 | test_acc=11.40% | test_loss=2.2813
# Round 02/15 | test_acc=11.95% | test_loss=2.2554
# Round 03/15 | test_acc=23.93% | test_loss=2.2489
# Round 04/15 | test_acc=21.23% | test_loss=2.2433
# Round 05/15 | test_acc=30.44% | test_loss=2.2375
# Round 06/15 | test_acc=27.64% | test_loss=2.2275
# Round 07/15 | test_acc=34.36% | test_loss=2.2295
# Round 08/15 | test_acc=29.84% | test_loss=2.2125
# Round 09/15 | test_acc=36.12% | test_loss=2.2116
# Round 10/15 | test_acc=31.97% | test_loss=2.1951
# Round 11/15 | test_acc=38.11% | test_loss=2.1985
# Round 12/15 | test_acc=35.32% | test_loss=2.1905
# Round 13/15 | test_acc=39.33% | test_loss=2.1865
# Round 14/15 | test_acc=36.03% | test_loss=2.1724
# Round 15/15 | test_acc=37.87% | test_loss=2.1840
#
# === alpha=0.5 | algo=FedSCAM_WA ===
# Round 01/15 | test_acc=13.08% | test_loss=2.2834
# Round 02/15 | test_acc=16.65% | test_loss=2.2557
# Round 03/15 | test_acc=22.87% | test_loss=2.2523
# Round 04/15 | test_acc=20.33% | test_loss=2.2458
# Round 05/15 | test_acc=27.68% | test_loss=2.2465
# Round 06/15 | test_acc=22.43% | test_loss=2.2444
# Round 07/15 | test_acc=30.74% | test_loss=2.2351
# Round 08/15 | test_acc=20.10% | test_loss=2.2385
# Round 09/15 | test_acc=32.12% | test_loss=2.2385
# Round 10/15 | test_acc=24.39% | test_loss=2.2319
# Round 11/15 | test_acc=34.03% | test_loss=2.2229
# Round 12/15 | test_acc=25.50% | test_loss=2.2213
# Round 13/15 | test_acc=34.71% | test_loss=2.2198
# Round 14/15 | test_acc=24.49% | test_loss=2.2263
# Round 15/15 | test_acc=34.97% | test_loss=2.2128
#
# === alpha=0.5 | algo=FedSAM ===
# Round 01/15 | test_acc=10.00% | test_loss=2.2894
# Round 02/15 | test_acc=10.43% | test_loss=2.2606
# Round 03/15 | test_acc=15.06% | test_loss=2.2606
# Round 04/15 | test_acc=19.71% | test_loss=2.2341
# Round 05/15 | test_acc=23.62% | test_loss=2.2425
# Round 06/15 | test_acc=24.24% | test_loss=2.2189
# Round 07/15 | test_acc=24.64% | test_loss=2.2258
# Round 08/15 | test_acc=26.29% | test_loss=2.2154
# Round 09/15 | test_acc=21.93% | test_loss=2.2190
# Round 10/15 | test_acc=26.07% | test_loss=2.2101
# Round 11/15 | test_acc=22.14% | test_loss=2.2116
# Round 12/15 | test_acc=28.45% | test_loss=2.2014
# Round 13/15 | test_acc=20.78% | test_loss=2.2083
# Round 14/15 | test_acc=25.22% | test_loss=2.2057
# Round 15/15 | test_acc=21.08% | test_loss=2.2030
#
# === alpha=0.5 | algo=FedLESAM ===
# Round 01/15 | test_acc=18.23% | test_loss=2.2776
# Round 02/15 | test_acc=21.99% | test_loss=2.2346
# Round 03/15 | test_acc=19.39% | test_loss=2.2590
# Round 04/15 | test_acc=21.51% | test_loss=2.2273
# Round 05/15 | test_acc=24.11% | test_loss=2.2443
# Round 06/15 | test_acc=22.03% | test_loss=2.2289
# Round 07/15 | test_acc=20.99% | test_loss=2.2432
# Round 08/15 | test_acc=23.43% | test_loss=2.2242
# Round 09/15 | test_acc=28.91% | test_loss=2.2181
# Round 10/15 | test_acc=23.88% | test_loss=2.2352
# Round 11/15 | test_acc=31.96% | test_loss=2.1998
# Round 12/15 | test_acc=22.94% | test_loss=2.2245
# Round 13/15 | test_acc=34.73% | test_loss=2.1940
# Round 14/15 | test_acc=26.27% | test_loss=2.2160
# Round 15/15 | test_acc=33.51% | test_loss=2.1977
#
# === alpha=0.5 | algo=FedWMSAM ===
# Round 01/15 | test_acc=14.73% | test_loss=2.2992
# Round 02/15 | test_acc=15.32% | test_loss=2.2969
# Round 03/15 | test_acc=13.96% | test_loss=2.2942
# Round 04/15 | test_acc=14.03% | test_loss=2.2887
# Round 05/15 | test_acc=14.69% | test_loss=2.2801
# Round 06/15 | test_acc=15.53% | test_loss=2.2689
# Round 07/15 | test_acc=16.37% | test_loss=2.2559
# Round 08/15 | test_acc=17.18% | test_loss=2.2420
# Round 09/15 | test_acc=18.97% | test_loss=2.2286
# Round 10/15 | test_acc=21.65% | test_loss=2.2173
# Round 11/15 | test_acc=25.79% | test_loss=2.2100
# Round 12/15 | test_acc=28.80% | test_loss=2.2073
# Round 13/15 | test_acc=29.34% | test_loss=2.2076
# Round 14/15 | test_acc=28.38% | test_loss=2.2088
# Round 15/15 | test_acc=26.24% | test_loss=2.2086
#
# === alpha=0.5 | algo=FedLWSAM ===
# Round 01/15 | test_acc=15.66% | test_loss=2.2904
# Round 02/15 | test_acc=16.45% | test_loss=2.2609
# Round 03/15 | test_acc=24.33% | test_loss=2.2655
# Round 04/15 | test_acc=20.85% | test_loss=2.2398
# Round 05/15 | test_acc=28.55% | test_loss=2.2431
# Round 06/15 | test_acc=26.26% | test_loss=2.2294
# Round 07/15 | test_acc=29.36% | test_loss=2.2252
# Round 08/15 | test_acc=32.00% | test_loss=2.2175
# Round 09/15 | test_acc=30.53% | test_loss=2.2192
# Round 10/15 | test_acc=31.74% | test_loss=2.2210
# Round 11/15 | test_acc=30.76% | test_loss=2.2121
# Round 12/15 | test_acc=31.74% | test_loss=2.2120
# Round 13/15 | test_acc=30.15% | test_loss=2.2106
# Round 14/15 | test_acc=32.12% | test_loss=2.2116
# Round 15/15 | test_acc=29.86% | test_loss=2.1931
#
# === alpha=0.5 | algo=FedSCAM_SAM ===
# Round 01/15 | test_acc=10.00% | test_loss=2.2859
# Round 02/15 | test_acc=11.93% | test_loss=2.2534
# Round 03/15 | test_acc=16.72% | test_loss=2.2527
# Round 04/15 | test_acc=18.43% | test_loss=2.2314
# Round 05/15 | test_acc=20.56% | test_loss=2.2316
# Round 06/15 | test_acc=23.45% | test_loss=2.2254
# Round 07/15 | test_acc=26.50% | test_loss=2.2230
# Round 08/15 | test_acc=27.24% | test_loss=2.2019
# Round 09/15 | test_acc=29.76% | test_loss=2.2188
# Round 10/15 | test_acc=27.21% | test_loss=2.1907
# Round 11/15 | test_acc=28.60% | test_loss=2.2129
# Round 12/15 | test_acc=29.34% | test_loss=2.1957
# Round 13/15 | test_acc=29.35% | test_loss=2.2062
# Round 14/15 | test_acc=32.97% | test_loss=2.1872
# Round 15/15 | test_acc=30.47% | test_loss=2.1955
#
# === alpha=0.5 | algo=FedSCAM_FULL ===
# Round 01/15 | test_acc=15.02% | test_loss=2.2966
# Round 02/15 | test_acc=12.12% | test_loss=2.2658
# Round 03/15 | test_acc=25.72% | test_loss=2.2630
# Round 04/15 | test_acc=26.70% | test_loss=2.2394
# Round 05/15 | test_acc=25.87% | test_loss=2.2520
# Round 06/15 | test_acc=29.57% | test_loss=2.2326
# Round 07/15 | test_acc=28.17% | test_loss=2.2397
# Round 08/15 | test_acc=29.56% | test_loss=2.2199
# Round 09/15 | test_acc=28.44% | test_loss=2.2261
# Round 10/15 | test_acc=30.78% | test_loss=2.2112
# Round 11/15 | test_acc=29.58% | test_loss=2.2238
# Round 12/15 | test_acc=29.12% | test_loss=2.2021
# Round 13/15 | test_acc=28.11% | test_loss=2.2227
# Round 14/15 | test_acc=29.74% | test_loss=2.2018
# Round 15/15 | test_acc=27.39% | test_loss=2.2139
#
# === alpha=1.0 | algo=FedAvg ===
# Round 01/15 | test_acc=14.62% | test_loss=2.2720
# Round 02/15 | test_acc=17.86% | test_loss=2.2488
# Round 03/15 | test_acc=19.07% | test_loss=2.2442
# Round 04/15 | test_acc=19.99% | test_loss=2.2398
# Round 05/15 | test_acc=23.50% | test_loss=2.2357
# Round 06/15 | test_acc=25.17% | test_loss=2.2254
# Round 07/15 | test_acc=22.62% | test_loss=2.2248
# Round 08/15 | test_acc=23.50% | test_loss=2.2185
# Round 09/15 | test_acc=25.88% | test_loss=2.2152
# Round 10/15 | test_acc=25.80% | test_loss=2.2125
# Round 11/15 | test_acc=27.29% | test_loss=2.2028
# Round 12/15 | test_acc=28.92% | test_loss=2.2003
# Round 13/15 | test_acc=28.26% | test_loss=2.1995
# Round 14/15 | test_acc=23.46% | test_loss=2.1969
# Round 15/15 | test_acc=27.04% | test_loss=2.1941
#
# === alpha=1.0 | algo=Uniform ===
# Round 01/15 | test_acc=16.71% | test_loss=2.2636
# Round 02/15 | test_acc=24.37% | test_loss=2.2339
# Round 03/15 | test_acc=23.82% | test_loss=2.2327
# Round 04/15 | test_acc=25.52% | test_loss=2.2273
# Round 05/15 | test_acc=25.68% | test_loss=2.2236
# Round 06/15 | test_acc=25.96% | test_loss=2.2179
# Round 07/15 | test_acc=26.54% | test_loss=2.2117
# Round 08/15 | test_acc=30.41% | test_loss=2.2045
# Round 09/15 | test_acc=27.71% | test_loss=2.1992
# Round 10/15 | test_acc=28.45% | test_loss=2.1935
# Round 11/15 | test_acc=30.30% | test_loss=2.1914
# Round 12/15 | test_acc=30.70% | test_loss=2.1795
# Round 13/15 | test_acc=31.77% | test_loss=2.1890
# Round 14/15 | test_acc=30.60% | test_loss=2.1693
# Round 15/15 | test_acc=33.70% | test_loss=2.1795
#
# === alpha=1.0 | algo=FedProx ===
# Round 01/15 | test_acc=10.18% | test_loss=2.2749
# Round 02/15 | test_acc=10.54% | test_loss=2.2593
# Round 03/15 | test_acc=12.33% | test_loss=2.2496
# Round 04/15 | test_acc=13.91% | test_loss=2.2432
# Round 05/15 | test_acc=15.92% | test_loss=2.2317
# Round 06/15 | test_acc=17.25% | test_loss=2.2262
# Round 07/15 | test_acc=22.19% | test_loss=2.2170
# Round 08/15 | test_acc=21.07% | test_loss=2.2190
# Round 09/15 | test_acc=22.17% | test_loss=2.2127
# Round 10/15 | test_acc=27.66% | test_loss=2.2036
# Round 11/15 | test_acc=25.66% | test_loss=2.1958
# Round 12/15 | test_acc=29.04% | test_loss=2.1957
# Round 13/15 | test_acc=27.63% | test_loss=2.1920
# Round 14/15 | test_acc=28.93% | test_loss=2.1889
# Round 15/15 | test_acc=29.45% | test_loss=2.1825
#
# === alpha=1.0 | algo=qFedAvg ===
# Round 01/15 | test_acc=12.37% | test_loss=2.2739
# Round 02/15 | test_acc=14.74% | test_loss=2.2491
# Round 03/15 | test_acc=17.91% | test_loss=2.2412
# Round 04/15 | test_acc=23.73% | test_loss=2.2271
# Round 05/15 | test_acc=22.27% | test_loss=2.2243
# Round 06/15 | test_acc=24.32% | test_loss=2.2086
# Round 07/15 | test_acc=28.94% | test_loss=2.2083
# Round 08/15 | test_acc=25.89% | test_loss=2.1986
# Round 09/15 | test_acc=29.74% | test_loss=2.1955
# Round 10/15 | test_acc=28.08% | test_loss=2.1902
# Round 11/15 | test_acc=29.48% | test_loss=2.1865
# Round 12/15 | test_acc=31.23% | test_loss=2.1869
# Round 13/15 | test_acc=32.38% | test_loss=2.1749
# Round 14/15 | test_acc=29.48% | test_loss=2.1684
# Round 15/15 | test_acc=32.36% | test_loss=2.1635
#
# === alpha=1.0 | algo=FedAvgM ===
# Round 01/15 | test_acc=11.21% | test_loss=2.2996
# Round 02/15 | test_acc=13.43% | test_loss=2.2926
# Round 03/15 | test_acc=13.62% | test_loss=2.2836
# Round 04/15 | test_acc=14.23% | test_loss=2.2711
# Round 05/15 | test_acc=14.98% | test_loss=2.2554
# Round 06/15 | test_acc=15.63% | test_loss=2.2374
# Round 07/15 | test_acc=16.28% | test_loss=2.2194
# Round 08/15 | test_acc=17.41% | test_loss=2.2032
# Round 09/15 | test_acc=18.55% | test_loss=2.1900
# Round 10/15 | test_acc=20.46% | test_loss=2.1804
# Round 11/15 | test_acc=23.23% | test_loss=2.1737
# Round 12/15 | test_acc=25.81% | test_loss=2.1709
# Round 13/15 | test_acc=27.27% | test_loss=2.1712
# Round 14/15 | test_acc=27.72% | test_loss=2.1736
# Round 15/15 | test_acc=27.56% | test_loss=2.1754
#
# === alpha=1.0 | algo=FedLW ===
# Round 01/15 | test_acc=10.08% | test_loss=2.2749
# Round 02/15 | test_acc=13.69% | test_loss=2.2467
# Round 03/15 | test_acc=11.75% | test_loss=2.2418
# Round 04/15 | test_acc=14.54% | test_loss=2.2322
# Round 05/15 | test_acc=14.23% | test_loss=2.2246
# Round 06/15 | test_acc=16.08% | test_loss=2.2143
# Round 07/15 | test_acc=14.03% | test_loss=2.2070
# Round 08/15 | test_acc=15.93% | test_loss=2.2032
# Round 09/15 | test_acc=17.73% | test_loss=2.1933
# Round 10/15 | test_acc=17.43% | test_loss=2.1900
# Round 11/15 | test_acc=17.03% | test_loss=2.1775
# Round 12/15 | test_acc=20.96% | test_loss=2.1697
# Round 13/15 | test_acc=20.34% | test_loss=2.1697
# Round 14/15 | test_acc=20.11% | test_loss=2.1662
# Round 15/15 | test_acc=20.58% | test_loss=2.1549
#
# === alpha=1.0 | algo=FedSCAM_WA ===
# Round 01/15 | test_acc=14.33% | test_loss=2.2676
# Round 02/15 | test_acc=12.03% | test_loss=2.2393
# Round 03/15 | test_acc=18.79% | test_loss=2.2323
# Round 04/15 | test_acc=20.60% | test_loss=2.2192
# Round 05/15 | test_acc=24.76% | test_loss=2.2148
# Round 06/15 | test_acc=26.12% | test_loss=2.2131
# Round 07/15 | test_acc=26.03% | test_loss=2.2026
# Round 08/15 | test_acc=23.51% | test_loss=2.1994
# Round 09/15 | test_acc=24.18% | test_loss=2.1922
# Round 10/15 | test_acc=26.77% | test_loss=2.1872
# Round 11/15 | test_acc=22.95% | test_loss=2.1812
# Round 12/15 | test_acc=28.01% | test_loss=2.1762
# Round 13/15 | test_acc=22.32% | test_loss=2.1818
# Round 14/15 | test_acc=26.09% | test_loss=2.1727
# Round 15/15 | test_acc=23.86% | test_loss=2.1702
#
# === alpha=1.0 | algo=FedSAM ===
# Round 01/15 | test_acc=16.82% | test_loss=2.2849
# Round 02/15 | test_acc=12.14% | test_loss=2.2426
# Round 03/15 | test_acc=15.97% | test_loss=2.2304
# Round 04/15 | test_acc=16.80% | test_loss=2.2115
# Round 05/15 | test_acc=17.03% | test_loss=2.2024
# Round 06/15 | test_acc=21.04% | test_loss=2.1892
# Round 07/15 | test_acc=18.47% | test_loss=2.1897
# Round 08/15 | test_acc=22.47% | test_loss=2.1804
# Round 09/15 | test_acc=22.06% | test_loss=2.1812
# Round 10/15 | test_acc=23.08% | test_loss=2.1741
# Round 11/15 | test_acc=23.02% | test_loss=2.1644
# Round 12/15 | test_acc=22.63% | test_loss=2.1659
# Round 13/15 | test_acc=25.79% | test_loss=2.1654
# Round 14/15 | test_acc=22.28% | test_loss=2.1615
# Round 15/15 | test_acc=24.96% | test_loss=2.1608
#
# === alpha=1.0 | algo=FedLESAM ===
# Round 01/15 | test_acc=10.09% | test_loss=2.2830
# Round 02/15 | test_acc=15.23% | test_loss=2.2595
# Round 03/15 | test_acc=20.78% | test_loss=2.2657
# Round 04/15 | test_acc=16.06% | test_loss=2.2554
# Round 05/15 | test_acc=24.42% | test_loss=2.2675
# Round 06/15 | test_acc=19.66% | test_loss=2.2433
# Round 07/15 | test_acc=27.05% | test_loss=2.2557
# Round 08/15 | test_acc=20.04% | test_loss=2.2371
# Round 09/15 | test_acc=29.39% | test_loss=2.2452
# Round 10/15 | test_acc=26.75% | test_loss=2.2276
# Round 11/15 | test_acc=29.85% | test_loss=2.2285
# Round 12/15 | test_acc=28.15% | test_loss=2.2285
# Round 13/15 | test_acc=29.54% | test_loss=2.2225
# Round 14/15 | test_acc=29.29% | test_loss=2.2235
# Round 15/15 | test_acc=32.48% | test_loss=2.2120
#
# === alpha=1.0 | algo=FedWMSAM ===
# Round 01/15 | test_acc=11.36% | test_loss=2.3007
# Round 02/15 | test_acc=10.46% | test_loss=2.2980
# Round 03/15 | test_acc=10.16% | test_loss=2.2951
# Round 04/15 | test_acc=10.09% | test_loss=2.2888
# Round 05/15 | test_acc=10.09% | test_loss=2.2783
# Round 06/15 | test_acc=10.09% | test_loss=2.2635
# Round 07/15 | test_acc=10.48% | test_loss=2.2456
# Round 08/15 | test_acc=11.76% | test_loss=2.2263
# Round 09/15 | test_acc=13.88% | test_loss=2.2065
# Round 10/15 | test_acc=16.09% | test_loss=2.1870
# Round 11/15 | test_acc=18.03% | test_loss=2.1677
# Round 12/15 | test_acc=19.62% | test_loss=2.1496
# Round 13/15 | test_acc=20.96% | test_loss=2.1341
# Round 14/15 | test_acc=21.73% | test_loss=2.1218
# Round 15/15 | test_acc=22.25% | test_loss=2.1125
#
# === alpha=1.0 | algo=FedLWSAM ===
# Round 01/15 | test_acc=10.82% | test_loss=2.2891
# Round 02/15 | test_acc=10.59% | test_loss=2.2655
# Round 03/15 | test_acc=14.81% | test_loss=2.2550
# Round 04/15 | test_acc=14.82% | test_loss=2.2373
# Round 05/15 | test_acc=22.58% | test_loss=2.2348
# Round 06/15 | test_acc=20.56% | test_loss=2.2246
# Round 07/15 | test_acc=26.02% | test_loss=2.2182
# Round 08/15 | test_acc=24.40% | test_loss=2.2152
# Round 09/15 | test_acc=26.27% | test_loss=2.1990
# Round 10/15 | test_acc=25.34% | test_loss=2.2009
# Round 11/15 | test_acc=26.50% | test_loss=2.1917
# Round 12/15 | test_acc=27.30% | test_loss=2.1889
# Round 13/15 | test_acc=29.91% | test_loss=2.1833
# Round 14/15 | test_acc=28.75% | test_loss=2.1814
# Round 15/15 | test_acc=28.65% | test_loss=2.1705
#
# === alpha=1.0 | algo=FedSCAM_SAM ===
# Round 01/15 | test_acc=17.27% | test_loss=2.2905
# Round 02/15 | test_acc=18.64% | test_loss=2.2498
# Round 03/15 | test_acc=20.87% | test_loss=2.2427
# Round 04/15 | test_acc=22.20% | test_loss=2.2342
# Round 05/15 | test_acc=25.50% | test_loss=2.2341
# Round 06/15 | test_acc=23.68% | test_loss=2.2241
# Round 07/15 | test_acc=25.00% | test_loss=2.2168
# Round 08/15 | test_acc=24.16% | test_loss=2.2166
# Round 09/15 | test_acc=24.29% | test_loss=2.2075
# Round 10/15 | test_acc=25.98% | test_loss=2.2091
# Round 11/15 | test_acc=22.87% | test_loss=2.1944
# Round 12/15 | test_acc=25.81% | test_loss=2.1961
# Round 13/15 | test_acc=23.03% | test_loss=2.1956
# Round 14/15 | test_acc=27.71% | test_loss=2.1831
# Round 15/15 | test_acc=27.08% | test_loss=2.1807
#
# === alpha=1.0 | algo=FedSCAM_FULL ===
# Round 01/15 | test_acc=19.33% | test_loss=2.2881
# Round 02/15 | test_acc=16.30% | test_loss=2.2564
# Round 03/15 | test_acc=15.47% | test_loss=2.2486
# Round 04/15 | test_acc=18.28% | test_loss=2.2424
# Round 05/15 | test_acc=19.18% | test_loss=2.2335
# Round 06/15 | test_acc=20.27% | test_loss=2.2270
# Round 07/15 | test_acc=23.01% | test_loss=2.2088
# Round 08/15 | test_acc=24.73% | test_loss=2.2069
# Round 09/15 | test_acc=25.72% | test_loss=2.1953
# Round 10/15 | test_acc=23.76% | test_loss=2.1917
# Round 11/15 | test_acc=27.57% | test_loss=2.1848
# Round 12/15 | test_acc=27.35% | test_loss=2.1808
# Round 13/15 | test_acc=27.97% | test_loss=2.1705
# Round 14/15 | test_acc=27.67% | test_loss=2.1665
# Round 15/15 | test_acc=32.00% | test_loss=2.1630
#     alpha          algo  final_acc  best_acc
# 1     0.1       Uniform     0.2442    0.2559
# 2     0.1       FedProx     0.2317    0.2726
# 7     0.1        FedSAM     0.2252    0.2412
# 4     0.1       FedAvgM     0.2200    0.2200
# 9     0.1      FedWMSAM     0.2128    0.2172
# 6     0.1    FedSCAM_WA     0.2127    0.2200
# 3     0.1       qFedAvg     0.1825    0.2425
# 10    0.1      FedLWSAM     0.1803    0.2509
# 0     0.1        FedAvg     0.1784    0.2158
# 11    0.1   FedSCAM_SAM     0.1623    0.2018
# 5     0.1         FedLW     0.1528    0.2035
# 12    0.1  FedSCAM_FULL     0.1448    0.2159
# 8     0.1      FedLESAM     0.1283    0.2367
# 18    0.5         FedLW     0.3787    0.3933
# 19    0.5    FedSCAM_WA     0.3497    0.3497
# 15    0.5       FedProx     0.3409    0.3623
# 14    0.5       Uniform     0.3400    0.3400
# 21    0.5      FedLESAM     0.3351    0.3473
# 16    0.5       qFedAvg     0.3182    0.3315
# 24    0.5   FedSCAM_SAM     0.3047    0.3297
# 23    0.5      FedLWSAM     0.2986    0.3212
# 13    0.5        FedAvg     0.2859    0.3310
# 25    0.5  FedSCAM_FULL     0.2739    0.3078
# 22    0.5      FedWMSAM     0.2624    0.2934
# 17    0.5       FedAvgM     0.2450    0.2450
# 20    0.5        FedSAM     0.2108    0.2845
# 27    1.0       Uniform     0.3370    0.3370
# 34    1.0      FedLESAM     0.3248    0.3248
# 29    1.0       qFedAvg     0.3236    0.3238
# 38    1.0  FedSCAM_FULL     0.3200    0.3200
# 28    1.0       FedProx     0.2945    0.2945
# 36    1.0      FedLWSAM     0.2865    0.2991
# 30    1.0       FedAvgM     0.2756    0.2772
# 37    1.0   FedSCAM_SAM     0.2708    0.2771
# 26    1.0        FedAvg     0.2704    0.2892
# 33    1.0        FedSAM     0.2496    0.2579
# 32    1.0    FedSCAM_WA     0.2386    0.2801
# 35    1.0      FedWMSAM     0.2225    0.2225
# 31    1.0         FedLW     0.2058    0.2096

# %%
WA_ALGOS = ["FedAvg","Uniform","FedProx","qFedAvg","FedAvgM","FedLW","FedSCAM_WA"]
SAM_ALGOS = ["FedSAM","FedLESAM","FedWMSAM","FedLWSAM","FedSCAM_SAM"]
FULL = ["FedSCAM_FULL"]

for alpha in cfg.alphas:
    res = all_results[alpha]

    plot_group(res, alpha, WA_ALGOS, "WA-only ablation (NO SAM): FedSCAM_WA vs weighted/WA baselines")
    plot_group(res, alpha, SAM_ALGOS, "SAM-only ablation (NO WA): FedSCAM_SAM vs SAM-family baselines")

    key = ["FedAvg","FedLW","FedSAM","FedLESAM","FedWMSAM","FedSCAM_WA","FedSCAM_SAM","FedSCAM_FULL"]
    plot_group(res, alpha, key, "Full comparison (key methods)")

# %%
# Toggle 1: FedBN off/on (can matter a lot in non-iid)
# cfg.use_fedbn = False

# Toggle 2: loss-weighting direction:
# cfg.lw_mode = "downweight_hard"  # vs "upweight_hard"

# Toggle 3: adaptive rho mode:
# cfg.adaptive_rho_mode = "loss"  # vs "grad_norm"

# Toggle 4: fixed rho to compare against adaptive rho:
# cfg.sam_rho = 0.05
# cfg.sam_rho_min = 0.05
# cfg.sam_rho_max = 0.05
